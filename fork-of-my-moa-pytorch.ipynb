# %% [markdown]
# ## Version 9.0
# Creating a model to predict the non-scored target variables, and then use those predictions as features to our original model.
# Default settings:
# VAR_THRESH=0.5
# PCA_VAR_THRESH = 0.98
# Category_Encoding = "OHE"
# Normalization = True
#
# Main Model:
# EPOCHS = 30
# BATCH_SIZE = 128
# LEARNING_RATE = 1e-3
# WEIGHT_DECAY = 1e-5
# NFOLDS = 7
# HIDDEN_SIZE=1024
#
# Label_Smoothing = True
# SMOOTHING = 0.000625
# CLAMPING = False
#
# Bad Values forced to 1.75/3624 (can be improved)
# ## Version 9.1 - identical LB
# just 1 seed
# Raw CV log_loss: 0.01603718902444793
# Adj CV log_loss: 0.014780029530755
# Raw roc_score: 0.7781
# Adj roc_score: 0.7989
#
# 5-seeds:
# Raw CV log_loss: 0.01584351028177877
# Adj CV log_loss: 0.014601615043857657
# Raw roc_score: 0.791
# Adj roc_score: 0.8106
# LB: 0.01848
#
# ## Version 9.20
# Working with nonscored targets only
#
# ## Version 9.21 - identical LB
# Same input to model A (all nonscored only) but Variance threshold the model_A features going into model B with 95% var thresh
# total features used: 10
# 1-seed
# Raw CV log_loss: 0.01600926011025232
# Adj CV log_loss: 0.014754283129646406
# Raw roc_score: 0.7824
# Adj roc_score: 0.8027
# 5-seed
# Raw CV log_loss: 0.015845303240007352
# Adj CV log_loss: 0.01460326278177118
# Raw roc_score: 0.7924
# Adj roc_score: 0.8120
# LB: 0.01848
#
# ## Version 9.22 - good
# Same input to model A (all nonscored only) but reducing columns to those with high correlation
# 70% correlation thresh -> 11 features kept
# 1-seed
# Raw CV log_loss: 0.015997520303735545
# Adj CV log_loss: 0.0147435619725201
# Raw roc_score: 0.7831
# Adj roc_score: 0.8033
#
# ## Version 9.23 - 1 seed is better than 9.21 but 5 is worse
# 9.22 but applying before model A to its inputs and therefore outputs
# 1-seed
# Raw CV log_loss: 0.01599122035932831
# Adj CV log_loss: 0.014737788706174525
# Raw roc_score: 0.7837
# Adj roc_score: 0.804
# 5-seed
# Raw CV log_loss: 0.01583948631723199
# Adj CV log_loss: 0.014597970510404484
# Raw roc_score: 0.7915
# Adj roc_score: 0.8108
#
# ## Version 9.30
# will be the same as 9.20 but using both scored and nonscored targets rather than just nonscored
#
# skipping 9.31 (Var Thresh)
# ## Version 9.32
# all targets (scored+nonscored) to model A. All outputs directly to Model B.
# Raw CV log_loss: 0.016141224959917627
# Adj CV log_loss: 0.014876034246844087
# Raw roc_score: 0.7774
# Adj roc_score: 0.7979
#
# ## Version 9.33 - good roc
# all targets (scored+nonscored) to model A. Reduced by correlation to model B
# features kept: 11
#
# Raw CV log_loss: 0.01602479924561013
# Adj CV log_loss: 0.014768721308772334
# Raw roc_score: 0.7844
# Adj roc_score: 0.8045
#
# 5-seed
# Raw CV log_loss: 0.015840346076463094
# Adj CV log_loss: 0.014598703743636634
# Raw roc_score: 0.7908
# Adj roc_score: 0.8104
#
# ## Version 9.34 - worse
# filtered targets (scored+nonscored) to model A.
# features kept: 24
# Raw CV log_loss: 0.01600459431257697
# Adj CV log_loss: 0.014749886220585652
# Raw roc_score: 0.7804
# Adj roc_score: 0.801
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////
# ## Version 8.0
# Random tries here:
# - change model slightly with extra 206 layer
# - clipping in val/inference to match training
# - forced results for the two columns with only 1 instance in training
# - pca componets set by var thresh
#
# For most steps will not be doing many seeds to save time.
# Default score for 1 seed(42):
# Raw CV log_loss:  0.015907815584041533
# Adj CV log_loss:  0.01466132260176977
# RAW roc_score: 0.7863
# Adj roc_score: 0.8031
#
# ## Version 8.1 - much worse
# Model change
# Raw CV log_loss:  0.01634822020906415
# Adj CV log_loss:  0.015067218323193998
#
# ## Version 8.2x - slightly worse
#
# ## Version 8.3x - slightly better
# Forcing the predictions for the two columns with only one training instance
# Value is forced to 1.25/3624
# Then forcing the control cases back to 0 (instead of 1.25/3624)
#
# Raw CV log_loss:  0.015907815584041533
# Adj CV log_loss:  0.014659818110153527
# Raw roc_score: 0.7863
# Adj roc_score: 0.8062
# LB: 0.01853
#
# ## Version 8.4x - same
# Using PCA components based on variance threshold. Slightly worse CV scores, but same LB score of 0.01853 this way.
# More applicable for after feature engineering steps incorporated.
# Setting PCA Var Thresh to 0.95 (95% of variance), slightly higher may be better.
# Deleting original cell columns.
#
# this results in 43 components(instead of 84)
# Raw CV log_loss: 0.01599883052723593
# Adj CV log_loss: 0.014743785098841774
# Raw roc_score: 0.7857
# Adj roc_score: 0.8042
# LB: 0.01853
#
# ## Version 8.50
# Transitioning model to put sigmoid function at the end of the model
# Funcitonizing the training functions to pass in train and test data
# Raw CV log_loss: 0.014708862352015383
# Adj CV log_loss: 0.014708862352015383
# Raw roc_score: 0.7854
# Adj roc_score: 0.8052
#
# 10 seeds (sticking with one model)
# Raw CV log_loss: 0.015801422229130252
# Adj CV log_loss: 0.014561736410029507
# Raw roc_score: 0.7972
# Adj roc_score: 0.8161
#
# ## Version 8.60
# Consolidating 8.xx.
# Difference between current version and 7.x is the forced results for the two bad columns, the sigmoid done separately, and the PCA handled differently.
# 8.50 - 5 seeds
# Raw CV log_loss: 0.01584497716551068
# Adj CV log_loss: 0.0146019428902391
# Raw roc_score: 0.7952
# Adj roc_score: 0.8144
# LB: 0.01849
#
# 7.x - 5 seeds
# Raw CV log_loss:  0.01577945871846186
# Adj CV log_loss:  0.014543023429612946
# Likely the PCA  or forced columns. is hurting the score the most.
# LB: 0.01849
#
# Options:
# 1. Can increase from 95% to 98% to more closely match the pca = 50 of 7.x
# 2. Can change the forced value to 1.75 rather than 1.25
# LB: 0.01848
#
# ## Version 8.70
# Forcing all feature columns to start with 'f-' for easier tracking of features
# f-        -> features
# f-cat-    -> categorical (no point in scaling)
# f-c-      -> CELLS
# f-g-      -> GENES
# f-pca-c/g -> pca based on c/g
# f-mod1    -> features created from model1
#
# PCA_VAR_THRESH = 0.98
# n_components selected: 72
#
# Raw CV log_loss: 0.016035353981699037
# Adj CV log_loss: 0.01477851468963645
# Raw roc_score: 0.7813
# Adj roc_score: 0.8014
#
# /---------------------------------------------------------
# ## Version 7.x - big improvement
# Multiple Seeds (5)
# Raw CV log_loss:  0.01577945871846186
# Adj CV log_loss:  0.014543023429612946
# /---------------------------------------------------------
# ## Version 6.x
# Going forward with the changes from before:
# - Label smoothing = 0.000625
# - Variance Thresh = 0.5 (keep g-307)
# - NFOLDS = 7
# - PCA on Cells set to 50
# - Normalization
#
# Baseline:
# Raw CV log_loss:  0.016026379115994655
# Adj CV log_loss:  0.014770595819175811
# LB 0.01856
# /---------------------------------------------------------
# ## Version 5.x
# Difficult to tell the effect based on CV score so more attempts at the LB are required. Having to redo this section as originally I used a function from the kaggle board that didn't follow what actual label smoothing is. Proper function is now being used: SmoothBCEwLogits
#
# NEW RESULTS USING SmoothBCEwLogits
# smoothing-0.000625:
# Raw CV log_loss:  0.016026379115994655
# Adj CV log_loss:  0.014770595819175811
# LB 0.01856
#
# default no label smoothing:
# -30 epochs
# -batch=128
# Raw CV log_loss:  0.015904204943717852
# Adj CV log_loss:  0.014657994881360596
# LB: 0.01869
# /---------------------------------------------------------
# ## Version 4.x
# Only improvement was with slight variance threshold in 4.12
#
# Feature reduction techniques - not dimensionality reduciton
# Default with no normalization/scaling:
# Raw CV log_loss:  0.015904204943717852
# Adj CV log_loss:  0.014657994881360596
# /---
# Raw CV log_loss:  0.01589018266445189
# Adj CV log_loss:  0.014645071349600735
#
# ## Version 4.1x - marginal improvement
# Using a Variance Threshold
# This method removes columns that do not meet a particular variance threshold, keeping only columns that vary more.
# Unable to recreate negligable improvements in 4.13, so optimal is 4.12[thresh=0.5] with [g-307] forced to keep.
#
# ## Version 4.12
# --with threshold = 0.5
# Genes 762/772
# {'g-219', 'g-15', 'g-536', 'g-550', 'g-611', 'g-104', 'g-331', 'g-481', 'g-435', 'g-307'}
# Cells 100/100
# Raw CV log_loss:  0.015899487103769677
# Adj CV log_loss:  0.014653646718465562
#
# with intersection of tabnet feat impt:
# 10 intended drops, 1 actually
# Raw CV log_loss:  0.015928861997008548
# Adj CV log_loss:  0.014680719875297952
#
# Noticed that dropping only the 1 feature above hurt our score, so instead dropped the 9 of 10 other than the one I thought we should drop.
# Learned that we should keep the column no matter what: g-307
# Raw CV log_loss:  0.01589018266445189
# Adj CV log_loss:  0.014645071349600735
# /-------------------------------------------------------------
# ## Version 3.x - much worse
# Tried Quantile-Transformation and other transformers, with and without the -10's included, with no improvements
# Going back to some normalization techniques after seeing good results on the forums about rankgauss.
# * Turns out thank rankgauss is just forcing the distribution to match a gaussian. I coincidentally did the same. Results did not improve though.
#
# /-------------------------------------------------------------
# ## Version 2.x - slight improvement
# Feature Reduction Techniques
# Marginal improvement using PCA on CELLS only set to 50. No improvement using TSVD, or anything on GENES
# Default:
# with cheaty normalization included and -10 boolean not included
# Raw CV log_loss:  0.015902345318586596
# Adj CV log_loss: 0.014656280971375661
# LB: 0.01868
#
# /-------------------------------------------------------------
# ## Version 1.1 - slight improvement
# Trying various model hyperparameter modifications. Slight imprvement changing to NFOLDS=7 over the base of 5.
# NFOLDS = 7(5 is default)
# Raw CV log_loss:  0.015863682029151085
# Adj CV log_loss:  0.014620647231704439
# LB: 0.01868

# %% [markdown]
# # Methods/Techniques to Try
# - outlier/anamoly removal?
# - feature engineering
# - pca reduction by variance thresh
# - observing the loss from each target

# %% [markdown]
# # Contents
#
# - [Environment Setup](#Environment_Setup)
# - [Ensure Reproducibility](#Ensure_Reproducibility)
# - [HyperParameters - All](#HyperParameters_-_All)
# - [Competition Supplied Data](#Competition_Supplied_Data)
# - [Import Data](#Import_Data)
# - [PreProcessing](#PreProcessing)
# - [Initial Filtering](#Initial_Filtering)
# - [Feature Engineering](#Feature_Engineering)
# - [Feature Reduction](#Feature_Reduction)
# - [CV Folds](#CV_Folds)
# - [PyTorch Setup](#PyTorch_Setup)
# - [Training Process](#Training_Process)
# - [Results](#Results)
# - [Prepare Submission File](#Prepare_Submission_File)

# %% [markdown]
# <a id='Environment_Setup'></a>
# # Environment Setup

# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import os
import copy
import seaborn as sns

from sklearn import preprocessing
from sklearn.metrics import log_loss, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import QuantileTransformer

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel

from xgboost import XGBClassifier

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import sys
sys.path.append('../input/iterative-stratification/iterative-stratification-master')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Ensure Reproducibility

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed_everything(seed=42)

# %% [markdown]
# <a id='HyperParameters_-_All'></a>
# # HyperParameters - All

# %%
# INITIAL FILTERING PARAMETERS
Include_neg_10 = False
Variance_Threshold = True
VAR_THRESH=0.5
PCA_VAR = True
PCA_VAR_THRESH = 0.98

# %%
# PREPROCESSING PARAMETERS
Category_Encoding = "OHE"  # "OHE" or "Mapping"
Normalization = True
Scaling = False
Remove_Skewness = False
Quantile_Transforming = False

# %%
# FEATURE ENGINEERING PARAMETERS

# %%
# FEATURE REDUCTION PARAMETERS

# %%
# MODEL PARAMETERS
DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 30
BATCH_SIZE = 128
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-5
NFOLDS = 7
HIDDEN_SIZE=1024

Label_Smoothing = True
SMOOTHING = 0.000625
CLAMPING = False
CLAMP_MIN = 0.0001
CLAMP_MAX = 0.9999

# %%
# POSTPROCESSING PARAMETERS
FORCE_BAD_COLS = True

# %% [markdown]
# ### Hardcoded Features to Drop or Keep

# %%
KEPT_FEATURES = ['g-307']
DROPPED_FEATURES = []

# %% [markdown]
# <a id='Competition_Supplied_Data'></a>
# # Competition Supplied Data

# %% [markdown]
# ### Import Data

# %%
# 3 training related files
train_features = pd.read_csv('../input/lish-moa/train_features.csv')
train_targets_scored = pd.read_csv('../input/lish-moa/train_targets_scored.csv')
train_targets_nonscored = pd.read_csv('../input/lish-moa/train_targets_nonscored.csv')

# 2 test related files
test_features = pd.read_csv('../input/lish-moa/test_features.csv')
sample_submission = pd.read_csv('../input/lish-moa/sample_submission.csv')

# %% [markdown]
# ### Reformat/Reshape the data

# %%
# train merges the train features and targets
train = train_features.merge(train_targets_scored, on='sig_id')

# %%
# Then train drops the control cases and resets the pandas index
ctrl_train = train[train_features['cp_type'] == 'ctl_vehicle'].reset_index(drop=True)
train = train[train_features['cp_type']!='ctl_vehicle'].reset_index(drop=True)

# Similarly drop the control cases from the test set. Will later fill with 0.
ctrl_test = test_features[test_features['cp_type'] == 'ctl_vehicle'].reset_index(drop=True)
test = test_features[test_features['cp_type']!='ctl_vehicle'].reset_index(drop=True)

# Also drop these control cases from the nonscored target df
targets_nonscored = train_targets_nonscored[train_features['cp_type'] != 'ctl_vehicle'].reset_index(drop=True)

# %%
# target is a subset of train with just sig_id and the 206 target columns
target = train[train_targets_scored.columns]

# %%
# Drop the cp_type column. Homogenous in each df anyways
train = train.drop('cp_type', axis=1)
ctrl_train = ctrl_train.drop('cp_type', axis=1)
test = test.drop('cp_type', axis=1)
ctrl_test = ctrl_test.drop('cp_type', axis=1)

# %%
# Data Dimensions
print(f"train: {train.shape}")
print(f"ctrl_train: {ctrl_train.shape}")
print(f"target: {target.shape}")
print(f"nonscored_target: {targets_nonscored.shape}")
print()
print(f"test: {test.shape}")
print(f"ctrl_test: {ctrl_test.shape}")
print(f"sample_submission: {sample_submission.shape}")
# Out:
# train: (21948, 1081)
# ctrl_train: (1866, 1081)
# target: (21948, 207)
# nonscored_target: (21948, 403)
#
# test: (3624, 875)
# ctrl_test: (358, 875)
# sample_submission: (3982, 207)

# %% [markdown]
# ### Renaming Feature columns
# Forcing all feature columns to start with 'f-' for easier tracking of features:
# - f- -> features
# - f-cat- -> categorical (no point in scaling)
# - f-c- -> CELLS
# - f-g- -> GENES
# - f-pca-c/g -> pca based on c/g
# - f-model_A- -> features created from model A

# %%
# Categoricals
train = train.rename(columns={'cp_time': 'f-cat-cp_time', 
                              'cp_dose': 'f-cat-cp_dose'})
test = test.rename(columns={'cp_time': 'f-cat-cp_time', 
                            'cp_dose': 'f-cat-cp_dose'})
# Cells and Genes
train.columns = ['f-' + col if (col.startswith('c-') or col.startswith('g-')) else col for col in train.columns]
test.columns = ['f-' + col if (col.startswith('c-') or col.startswith('g-')) else col for col in test.columns]

# %% [markdown]
# ### Column Subsets

# %%
# List of column names for easy reference throughout
CAT_COLS = [col for col in test.columns if col.startswith('f-cat-')]
GENES = [col for col in test.columns if col.startswith('f-g-')]
CELLS = [col for col in test.columns if col.startswith('f-c-')]
temp_feature_cols = [col for col in test.columns if col.startswith('f-')]
target_cols = target.drop('sig_id', axis=1).columns.values.tolist()
targets_nonscored_cols = targets_nonscored.drop('sig_id', axis=1).columns.values.tolist()
# feature_cols not defined here because new features will be created and some will be dropped

# Column Data Dimensions
print(f"CAT_COLS: {len(CAT_COLS)}")
print(f"GENES: {len(GENES)}")
print(f"CELLS: {len(CELLS)}")
print()
print(f"Temp Feature Columns: {len(temp_feature_cols)}")
print(f"Target Columns: {len(target_cols)}")
print(f"Nonscored target Columns: {len(targets_nonscored_cols)}")
# Out:
# CAT_COLS: 2
# GENES: 772
# CELLS: 100
#
# Temp Feature Columns: 874
# Target Columns: 206
# Nonscored target Columns: 402

# %% [markdown]
# <a id='PreProcessing'></a>
# # PreProcessing

# %% [markdown]
# ### Quantile Transformation

# %%
if Quantile_Transforming:
#     all_data = pd.concat([pd.DataFrame(train[G_and_C]), pd.DataFrame(test[G_and_C])])
    non_cat_cols = list(set(temp_feature_cols) - set(CAT_COLS))
    all_data = pd.DataFrame(train[non_cat_cols])
    all_data_nans = all_data.copy()
#     all_data_nans[all_data == -10] = np.nan

    qt = QuantileTransformer(n_quantiles=100, output_distribution='normal', random_state=42)
    qt.fit(all_data_nans.values)
#     all_data_trans = qt.transform(all_data)

    train.loc[:, non_cat_cols] = qt.transform(train.loc[:, non_cat_cols])
    test.loc[:, non_cat_cols] = qt.transform(test.loc[:, non_cat_cols])

# %% [markdown]
# <a id='Initial_Filtering'></a>
# # Initial Filtering

# %% [markdown]
# ### Variance Threshold

# %%
var_drops = []
if Variance_Threshold:
    non_cat_cols = list(set(temp_feature_cols) - set(CAT_COLS))
    selector = VarianceThreshold(VAR_THRESH)
    all_data = pd.concat([pd.DataFrame(train[non_cat_cols]), pd.DataFrame(test[non_cat_cols])])
       
    selector.fit(all_data[non_cat_cols])
    kept_columns = all_data.columns.values[selector.get_support(indices=True)]
    dropped_columns = set(non_cat_cols) - set(kept_columns)
    
    var_drops = dropped_columns

print(f"Var drops: {len(var_drops)}")
# Out:
# Var drops: 10

# %% [markdown]
# ### Drop Features from Filters

# %%
dropped_features = var_drops

# Incorporate Forced keep and drop features
dropped_features = set(dropped_features).union(set(DROPPED_FEATURES))
dropped_features = set(dropped_features) - set(KEPT_FEATURES)


print(f"Var Dropped Features: {len(var_drops)}")
print(var_drops)
print(f"Total Dropped Features: {len(dropped_features)}")

train.drop(columns=dropped_features, inplace=True)
test.drop(columns=dropped_features, inplace=True)
# Out:
# Var Dropped Features: 10
# {'f-g-219', 'f-g-550', 'f-g-536', 'f-g-611', 'f-g-104', 'f-g-435', 'f-g-307', 'f-g-15', 'f-g-481', 'f-g-331'}
# Total Dropped Features: 10

# %% [markdown]
# ### Column Subsets

# %%
# List of column names for easy reference throughout
CAT_COLS = [col for col in test.columns if col.startswith('f-cat-')]
GENES = [col for col in test.columns if col.startswith('f-g-')]
CELLS = [col for col in test.columns if col.startswith('f-c-')]
temp_feature_cols = [col for col in test.columns if col.startswith('f-')]
target_cols = target.drop('sig_id', axis=1).columns.values.tolist()
targets_nonscored_cols = targets_nonscored.drop('sig_id', axis=1).columns.values.tolist()
# feature_cols not defined here because new features will be created and some will be dropped

# Column Data Dimensions
print(f"CAT_COLS: {len(CAT_COLS)}")
print(f"GENES: {len(GENES)}")
print(f"CELLS: {len(CELLS)}")
print()
print(f"Temp Feature Columns: {len(temp_feature_cols)}")
print(f"Target Columns: {len(target_cols)}")
print(f"Nonscored target Columns: {len(targets_nonscored_cols)}")
# Out:
# CAT_COLS: 2
# GENES: 762
# CELLS: 100
#
# Temp Feature Columns: 864
# Target Columns: 206
# Nonscored target Columns: 402

# %% [markdown]
# <a id='Feature_Engineering'></a>
# # Feature Engineering

# %% [markdown]
# ### -10 Boolean Columns

# %%
# Create Boolean columns for -10 cases

# Find Columns with an Unusual amount of -10 values -> I set a threshold of just 5 for now
if Include_neg_10:
    non_cat_cols = list(set(temp_feature_cols) - set(CAT_COLS))
    count_neg_10 = (train[non_cat_cols] == -10).astype(int).sum(axis=0)
    neg_10_cols = count_neg_10[count_neg_10 >= 5].index
    neg_10_bool_cols = ['f-cat-10-' + col for col in neg_10_cols] 
    len(neg_10_cols)

    train[neg_10_bool_cols] = 0
    for col, new_col in zip(neg_10_cols, neg_10_bool_cols):
        train.loc[train[train[col] == -10].index, new_col] = 1

    test[neg_10_bool_cols] = 0
    for col, new_col in zip(neg_10_cols, neg_10_bool_cols):
        test.loc[test[test[col] == -10].index, new_col] = 1

# %% [markdown]
# ### Column Subsets

# %%
# List of column names for easy reference throughout
CAT_COLS = [col for col in test.columns if col.startswith('f-cat-')]
GENES = [col for col in test.columns if col.startswith('f-g-')]
CELLS = [col for col in test.columns if col.startswith('f-c-')]
temp_feature_cols = [col for col in test.columns if col.startswith('f-')]
target_cols = target.drop('sig_id', axis=1).columns.values.tolist()
targets_nonscored_cols = targets_nonscored.drop('sig_id', axis=1).columns.values.tolist()
# feature_cols not defined here because new features will be created and some will be dropped

# Column Data Dimensions
print(f"CAT_COLS: {len(CAT_COLS)}")
print(f"GENES: {len(GENES)}")
print(f"CELLS: {len(CELLS)}")
print()
print(f"Temp Feature Columns: {len(temp_feature_cols)}")
print(f"Target Columns: {len(target_cols)}")
print(f"Nonscored target Columns: {len(targets_nonscored_cols)}")
# Out:
# CAT_COLS: 2
# GENES: 762
# CELLS: 100
#
# Temp Feature Columns: 864
# Target Columns: 206
# Nonscored target Columns: 402

# %% [markdown]
# <a id='Feature_Reduction'></a>
# # Feature Reduction

# %% [markdown]
# ### PCA Variance Threshold

# %%
# Only trying Cells right now

if PCA_VAR:
    data = pd.concat([pd.DataFrame(train[CELLS]), pd.DataFrame(test[CELLS])])
    scaler = MinMaxScaler()
    data.loc[:, CELLS] = scaler.fit_transform(data[CELLS])
    
    pca_cells = PCA(n_components = PCA_VAR_THRESH)
    data2 = pca_cells.fit_transform(data)
    
    num_pca_cell_comp = data2.shape[1]
    print(f"n_components selected: {num_pca_cell_comp}")
          
    train2 = data2[:train.shape[0]]
    test2 = data2[train.shape[0]:]
    
    train2 = pd.DataFrame(train2, columns=[f'f-pca-c-{i}' for i in range(num_pca_cell_comp)])
    test2 = pd.DataFrame(test2, columns=[f'f-pca-c-{i}' for i in range(num_pca_cell_comp)])
    
#     train = train.drop(columns=CELLS)
    train = pd.concat([train, train2], axis=1)
#     test = test.drop(columns=CELLS)
    test = pd.concat([test, test2], axis=1)
# Out:
# n_components selected: 72

# %% [markdown]
# ### Column Subsets

# %%
# List of column names for easy reference throughout
CAT_COLS = [col for col in test.columns if col.startswith('f-cat-')]
GENES = [col for col in test.columns if col.startswith('f-g-')]
CELLS = [col for col in test.columns if col.startswith('f-c-')]
temp_feature_cols = [col for col in test.columns if col.startswith('f-')]
target_cols = target.drop('sig_id', axis=1).columns.values.tolist()
targets_nonscored_cols = targets_nonscored.drop('sig_id', axis=1).columns.values.tolist()
# feature_cols not defined here because new features will be created and some will be dropped

# Column Data Dimensions
print(f"CAT_COLS: {len(CAT_COLS)}")
print(f"GENES: {len(GENES)}")
print(f"CELLS: {len(CELLS)}")
print()
print(f"Temp Feature Columns: {len(temp_feature_cols)}")
print(f"Target Columns: {len(target_cols)}")
print(f"Nonscored target Columns: {len(targets_nonscored_cols)}")
# Out:
# CAT_COLS: 2
# GENES: 762
# CELLS: 100
#
# Temp Feature Columns: 936
# Target Columns: 206
# Nonscored target Columns: 402

# %% [markdown]
# <a id='CV_Folds'></a>
# # CV Folds

# %%
# folds will be identical to train, but with a kfold column. 
# folds wll be used in the actual training
folds = train.copy()
mskf = MultilabelStratifiedKFold(n_splits=NFOLDS)

for f, (t_idx, v_idx) in enumerate(mskf.split(X=train, y=target)):
    folds.loc[v_idx, 'kfold'] = int(f)

folds['kfold'] = folds['kfold'].astype(int)

# %%
print(train.shape)
print(folds.shape)
print(test.shape)
print(target.shape)
print(sample_submission.shape)
# Out:
# (21948, 1143)
# (21948, 1144)
# (3624, 937)
# (21948, 207)
# (3982, 207)

# %% [markdown]
# <a id='PyTorch_Setup'></a>
# # PyTorch Setup

# %% [markdown]
# ### Define Dataset Classes

# %%
class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
        }
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }
        return dct

# %% [markdown]
# ### Define train/val/inference functions

# %%
def train_fn(model, optimizer, scheduler, loss_fn, dataloader, device):
    # Tell the model which mode it is in. At the very least this enables dropout for train mode only.
    model.train()
    final_loss = 0
    
    for data in dataloader:
        optimizer.zero_grad()
        inputs, targets = data['x'].to(device), data['y'].to(device)
#         print(inputs.shape)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        final_loss += loss.item()
        
    final_loss /= len(dataloader)
    
    return final_loss


def valid_fn(model, loss_fn, dataloader, device):
    # Tell the model which mode it is in. At the very least this disables dropout for eval mode.
    model.eval()
    final_loss = 0
    valid_preds = []
    
    for data in dataloader:
        inputs, targets = data['x'].to(device), data['y'].to(device)
        outputs = model(inputs)

        if CLAMPING:
            loss = loss_fn(torch.clamp(outputs, min=CLAMP_MIN, max=CLAMP_MAX), targets)
            valid_preds.append(torch.clamp(outputs, min=CLAMP_MIN, max=CLAMP_MAX).detach().cpu().numpy())
        else:
            loss = loss_fn(outputs, targets)
            valid_preds.append(outputs.detach().cpu().numpy())
            
        final_loss += loss.item()
        
    final_loss /= len(dataloader)
    valid_preds = np.concatenate(valid_preds)
    
    return final_loss, valid_preds

def inference_fn(model, dataloader, device):
    # Tell the model which mode it is in. At the very least this disables dropout for eval mode.
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs)
            
        if CLAMPING:
            preds.append(torch.clamp(outputs, min=CLAMP_MIN, max=CLAMP_MAX).detach().cpu().numpy())
        else:
            preds.append(outputs.detach().cpu().numpy())
        
    preds = np.concatenate(preds)
    
    return preds

# %% [markdown]
# ### Custom Label Smoothing Loss Function

# %%
import torch
from torch.nn.modules.loss import _WeightedLoss
import torch.nn.functional as F

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, smoothing=0.0):
        super().__init__()
        self.smoothing = smoothing

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        m = nn.Sigmoid()
        
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1), self.smoothing)
#         loss = F.binary_cross_entropy_with_logits(inputs, targets,)
        loss = F.binary_cross_entropy(inputs, targets,)
        loss = loss.mean()

        return loss

# %% [markdown]
# ### Define Models

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size, verbose=False):
        super(Model, self).__init__()    
        
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dropout1 = nn.Dropout(0.2)
        self.fc1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size))
        self.prelu1 = nn.PReLU()
        
        self.batch_norm2 = nn.BatchNorm1d(hidden_size)
        self.dropout2 = nn.Dropout(0.2)
        self.fc2 = nn.utils.weight_norm(nn.Linear(hidden_size, hidden_size))
        self.prelu2 = nn.PReLU()
        
        self.batch_norm3 = nn.BatchNorm1d(hidden_size)
        self.dropout3 = nn.Dropout(0.5)
        self.fc3 = nn.utils.weight_norm(nn.Linear(hidden_size, num_targets))
        self.sigmoid = nn.Sigmoid()
        
    # https://www.kaggle.com/c/lish-moa/discussion/188651
    def recalibrate_layer(self, layer):
        if(torch.isnan(layer.weight_v).sum() > 0):
            print ('recalibrate layer.weight_v')
            layer.weight_v = torch.nn.Parameter(torch.where(torch.isnan(layer.weight_v), torch.zeros_like(layer.weight_v), layer.weight_v))
            layer.weight_v = torch.nn.Parameter(layer.weight_v + 1e-10)

        if(torch.isnan(layer.weight).sum() > 0):
            print ('recalibrate layer.weight')
            layer.weight = torch.where(torch.isnan(layer.weight), torch.zeros_like(layer.weight), layer.weight)
            layer.weight += 1e-10
            
    def forward(self, x):
        # lesson learned here: do not use F.prelu. Worse results.
        
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        self.recalibrate_layer(self.fc1)
        x = self.prelu1(self.fc1(x))

        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        self.recalibrate_layer(self.fc2)
        x = self.prelu2(self.fc2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        self.recalibrate_layer(self.fc3)
        x = self.sigmoid(self.fc3(x))
        
        return x

# %% [markdown]
# ### Preprocessing Steps

# %%
def process_data(input_data):
    data = input_data.copy()
    non_cat_cols = list(set(temp_feature_cols) - set(CAT_COLS))
    ###### Category Encoding-----------------------------------------------------
    # One-Hot-Encoding
    if Category_Encoding == "OHE":
        data = pd.get_dummies(data, prefix='f-cat-OHE-', prefix_sep='', columns=CAT_COLS)
        print(f" Number of OHE columns added: {len([col for col in data.columns if col.startswith('f-cat-OHE-')])}")
    # Label-Encoding
    
    # Manual-Mapping
    if Category_Encoding == "Mapping":
        data.loc[:, 'f-cat-cp_time'] = data.loc[:, 'f-cat-cp_time'].map({24: 1, 48: 2, 72: 3}).values
        data.loc[:, 'f-cat-cp_dose'] = data.loc[:, 'f-cat-cp_dose'].map({'D1': 0, 'D2': 1}).values
    
    ###### Normalizing------------------------------------------------------------
    # normalizes the train against train and the test against test
    if Normalization:
        scaler = StandardScaler(with_mean=True, with_std=True)
        data.loc[:, non_cat_cols] = scaler.fit_transform(data.loc[:, non_cat_cols])
    
    ###### Scaling
    # scales the train against train and the test against test
    if Scaling:
        MinMaxscaler = MinMaxScaler(feature_range=(-1, 1))
        data.loc[:, non_cat_cols] = MinMaxscaler.fit_transform(data.loc[:, non_cat_cols])
    
    ###### Remove Skewness --------------------------------------------------------
    # Removing Skewness
    if Remove_Skewness:
        for col in non_cat_cols:
            if(abs(data[col].skew()) > 0.75):

                if(data[col].skew() < 0): # neg-skewness
                    data[col] = data[col].max() - data[col] + 1
                    data[col] = np.sqrt(data[col])

                else:
                    data[col] = np.sqrt(data[col])
    #------------------------------------------------------------------
    
    return data

# %% [markdown]
# <a id='Training_Process'></a>
# ## Training Process

# %% [markdown]
# ### Single Fold Training Function

# %%
def run_training(X_train, y_train, X_test, proc_feature_columns, target_columns, HyperParams, fold, seed):
    # List of global things passed into here that aren't identified
    # - valid_loss_array = np.zeros((EPOCHS, NFOLDS))
    # - seed_everything function to avoid randomness
    seed_everything(seed)

    # trn_idx is never used, but val_idx is. Both kept because it looks cleaner.
    trn_idx = X_train[X_train['kfold'] != fold].index
    val_idx = X_train[X_train['kfold'] == fold].index
    
    # For the current fold, separate the train(80%) and val(20%) data by the kfold column
    X_train_df = X_train[X_train['kfold'] != fold].reset_index(drop=True)
    X_valid_df = X_train[X_train['kfold'] == fold].reset_index(drop=True)
    y_train_df = y_train[X_train['kfold'] != fold].reset_index(drop=True)
    y_valid_df = y_train[X_train['kfold'] == fold].reset_index(drop=True)
    
    # separate the data by column and put into respective arrays
    x_train = X_train_df[proc_feature_columns].values
    y_train = y_train_df[target_columns].values
    x_valid = X_valid_df[proc_feature_columns].values
    y_valid = y_valid_df[target_columns].values
    
    # init class with the given train and val data
    train_dataset = MoADataset(x_train, y_train)
    valid_dataset = MoADataset(x_valid, y_valid)
    
    # DataLoader is set up as a 'Map-style' dataset 
    # a.k.a. it utilizes the --getitem-- and --len-- protocols we defined in the class
    
    # shuffle is good for training because we do not want any significance to order while training. 
    # Once the weights are determined, shuffle doesn't matter(for val and test)
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=HyperParams["BATCH_SIZE"], shuffle=True, num_workers=5, pin_memory=True)
    validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=HyperParams["BATCH_SIZE"], shuffle=False, num_workers=5, pin_memory=True)
    
    # Our model is simply the layers and forward function. These parameters define the model
    model = Model(
        num_features=len(proc_feature_columns),
        num_targets=len(target_columns),
        hidden_size=HIDDEN_SIZE,
    )
    
    # Device is set to cuda if available, else cpu (in the hyperparameter section)
    model.to(HyperParams["DEVICE"])
    
    # model.parameters() returns an iterator over the module parameters (most commonly used such as in this case, for the optimizer)
    # OneCycleLR looks to be a very fast learining rate convergence method.
    optimizer = torch.optim.Adam(model.parameters(), 
                                 lr=HyperParams["LEARNING_RATE"], 
                                 weight_decay=HyperParams["WEIGHT_DECAY"])
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, 
                                              pct_start=0.1, 
                                              div_factor=1e3, 
                                              max_lr=1e-2, 
                                              epochs=HyperParams["EPOCHS"], 
                                              steps_per_epoch=len(trainloader))
    
    if Label_Smoothing:
        loss_tr = SmoothBCEwLogits(smoothing=SMOOTHING)
    else:
        loss_tr = nn.BCELoss()
    
    loss_val = nn.BCELoss()

    # create array of zeros for oof predictions. Shape is num of observations x num targets
    oof = np.zeros((X_train.shape[0], len(target_columns)))

    # start off with a big number. Will update each cycle on improvements
    best_loss = np.inf
    
    # currently set for 30
    for epoch in range(HyperParams["EPOCHS"]):
        
        # In train_fn: return the loss for the data through our model. 
            # No predictions. 
            # We step the optimizer and scheduler.
        # In valid_fn: return loss and predictions
            # No training is done, as in weights/parameters are left unchanged
        train_loss = train_fn(model, optimizer,scheduler, loss_tr, trainloader, HyperParams["DEVICE"])
        print(f"SEED: {seed}, FOLD: {fold}, EPOCH: {epoch}, train_loss: {train_loss}")
        valid_loss, valid_preds = valid_fn(model, loss_val, validloader, HyperParams["DEVICE"])
        print(f"SEED: {seed}, FOLD: {fold}, EPOCH: {epoch}, valid_loss: {valid_loss}")
        valid_loss_array[epoch, fold] = valid_loss
        
        # if valid loss is the best so far, save the corresponding model
        if valid_loss < best_loss:
            
            best_loss = valid_loss
            oof[val_idx] = valid_preds
            torch.save(model.state_dict(), f"FOLD{fold}_.pth")
            
    #--------------------- PREDICTION---------------------
    # After training the model, load the best model based on validation results, and run once with the test data for its predictions
    x_test = X_test[proc_feature_columns].values
    testdataset = TestDataset(x_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=HyperParams["BATCH_SIZE"], shuffle=False)
    
    # not sure why the model is re-initialized here. Is, and hsould be, identical to the train/val model. 
    # The load_state is still necessary though.
    model = Model(
        num_features=len(proc_feature_columns),
        num_targets=len(target_columns),
        hidden_size=HIDDEN_SIZE,
    )
    
    model.load_state_dict(torch.load(f"FOLD{fold}_.pth"))
    model.to(HyperParams["DEVICE"])
    
    predictions = np.zeros((len(X_test), len(target_columns)))
    predictions = inference_fn(model, testloader, HyperParams["DEVICE"])
    
    # oof: The oof prediction array
    # predictions: The test set prediction array
    return oof, predictions

# %% [markdown]
# ### Multi-Fold Training  Function

# %%
def run_k_fold(X_train, y_train, X_test, feature_columns, target_columns, HyperParams, seed):
    # Set up the oof and predictions arrays to be filled each time.
    oof = np.zeros((X_train.shape[0], len(target_columns)))
    predictions = np.zeros((len(X_test), len(target_columns)))
    
    # Process Features here for X_train and X_test rather than every fold redoing it
    X_train = process_data(X_train)
    X_test = process_data(X_test)
    proc_feature_columns = [c for c in X_train.columns if c.startswith('f-')]
    
    for fold in range(HyperParams["NFOLDS"]):
        oof_, pred_ = run_training(X_train, y_train, X_test, proc_feature_columns, target_columns, HyperParams, fold, seed)
        
        # predictions happen each fold, this method averages the predicitons over all of the folds.
        predictions += pred_ / HyperParams["NFOLDS"]
        # Only a subset of the oof is nonzero each time corresponding to the fold
        oof += oof_
        
    return oof, predictions

# %% [markdown]
# ### Multi-Seed Training

# %%
# HyperParameters
HyperParams = {
    "EPOCHS": EPOCHS,
    "NFOLDS": NFOLDS,
    "DEVICE": DEVICE,
    "BATCH_SIZE": BATCH_SIZE,
    "HIDDEN_SIZE": HIDDEN_SIZE,
    "LEARNING_RATE": LEARNING_RATE,
    "WEIGHT_DECAY": WEIGHT_DECAY,
}

# %% [markdown]
# ### Input for Model A
# Model A will use the same parameters as our original model (for now).
# Model A trains with our original features but wiht the nonscored targets, to predict them.
# These predictions will then be used as features into our original model.

# %%
# List of seeds to run over.
SEEDS = [1, 2, 3, 4, 42]

# list of target/feature column names - should be 206 targets of them
target_columns = target_cols + targets_nonscored_cols
feature_columns = [c for c in folds.columns if c.startswith('f-')]

# training x and kfold column. Contains 'sig_id' column
X_train = folds[['sig_id'] + feature_columns + ['kfold']]
y_train = folds[['sig_id'] + target_cols].merge(targets_nonscored, on='sig_id', how='left')

# test data. Includes 'sig_id' and features, no target columns or kfold
X_test = test.copy()

# %% [markdown]
# ### Train Model A

# %%
# This chunk is just putting a wrapper around the main training function 'run_k_fold'
# To allow many SEEDs to be tested and averaged at once.

oof = np.zeros((X_train.shape[0], len(target_columns)))
predictions = np.zeros((len(X_test), len(target_columns)))
valid_loss_array = np.zeros((HyperParams["EPOCHS"], HyperParams["NFOLDS"]))

for seed in SEEDS:
    
    oof_, predictions_ = run_k_fold(X_train.copy(), y_train.copy(), X_test.copy(), feature_columns, target_columns, HyperParams, seed)
    oof += oof_ / len(SEEDS)
    predictions += predictions_ / len(SEEDS)

# Make new outputs later
Model_A_validation_predictions = X_train[['sig_id']]
Model_A_validation_predictions[target_columns] = oof

Model_A_test_predictions = X_test[['sig_id']]
Model_A_test_predictions[target_columns] = predictions
# Out:
#  Number of OHE columns added: 5
#  Number of OHE columns added: 5
# SEED: 42, FOLD: 0, EPOCH: 0, train_loss: 0.5825643211501796
# SEED: 42, FOLD: 0, EPOCH: 0, valid_loss: 0.05931144744157791
# SEED: 42, FOLD: 0, EPOCH: 1, train_loss: 0.02359189063652742
# SEED: 42, FOLD: 0, EPOCH: 1, valid_loss: 0.010474060103297234
# SEED: 42, FOLD: 0, EPOCH: 2, train_loss: 0.015347148811279916
# SEED: 42, FOLD: 0, EPOCH: 2, valid_loss: 0.00886984599288553
# SEED: 42, FOLD: 0, EPOCH: 3, train_loss: 0.012691231868958392
# SEED: 42, FOLD: 0, EPOCH: 3, valid_loss: 0.00802850014064461
# SEED: 42, FOLD: 0, EPOCH: 4, train_loss: 0.011640394684624206
# SEED: 42, FOLD: 0, EPOCH: 4, valid_loss: 0.008378132614307105
# SEED: 42, FOLD: 0, EPOCH: 5, train_loss: 0.010198264526912854
# SEED: 42, FOLD: 0, EPOCH: 5, valid_loss: 0.007741141540464014
# SEED: 42, FOLD: 0, EPOCH: 6, train_loss: 0.010791424627029369
# SEED: 42, FOLD: 0, EPOCH: 6, valid_loss: 0.007465449022129178
# SEED: 42, FOLD: 0, EPOCH: 7, train_loss: 0.010162320547122634
# SEED: 42, FOLD: 0, EPOCH: 7, valid_loss: 0.007716301088221371
# SEED: 42, FOLD: 0, EPOCH: 8, train_loss: 0.009476952989693402
# SEED: 42, FOLD: 0, EPOCH: 8, valid_loss: 0.008128287820145488
# SEED: 42, FOLD: 0, EPOCH: 9, train_loss: 0.009039602901305066
# SEED: 42, FOLD: 0, EPOCH: 9, valid_loss: 0.007856167634017766
# SEED: 42, FOLD: 0, EPOCH: 10, train_loss: 0.009038392946973037
# SEED: 42, FOLD: 0, EPOCH: 10, valid_loss: 0.00778833928052336
# SEED: 42, FOLD: 0, EPOCH: 11, train_loss: 0.008791659855708277
# SEED: 42, FOLD: 0, EPOCH: 11, valid_loss: 0.007655404852703214
# SEED: 42, FOLD: 0, EPOCH: 12, train_loss: 0.008404122478626415
# SEED: 42, FOLD: 0, EPOCH: 12, valid_loss: 0.007428405038081109
# SEED: 42, FOLD: 0, EPOCH: 13, train_loss: 0.008321490468216591
# SEED: 42, FOLD: 0, EPOCH: 13, valid_loss: 0.00725659430027008
# SEED: 42, FOLD: 0, EPOCH: 14, train_loss: 0.00819123958294489
# SEED: 42, FOLD: 0, EPOCH: 14, valid_loss: 0.007244292364921421
# SEED: 42, FOLD: 0, EPOCH: 15, train_loss: 0.008187496776496168
# SEED: 42, FOLD: 0, EPOCH: 15, valid_loss: 0.007126161549240351
# SEED: 42, FOLD: 0, EPOCH: 16, train_loss: 0.007537528853483346
# SEED: 42, FOLD: 0, EPOCH: 16, valid_loss: 0.007481590192764997
# SEED: 42, FOLD: 0, EPOCH: 17, train_loss: 0.007378850377728643
# SEED: 42, FOLD: 0, EPOCH: 17, valid_loss: 0.007343886066228151
# SEED: 42, FOLD: 0, EPOCH: 18, train_loss: 0.007004333018534341
# SEED: 42, FOLD: 0, EPOCH: 18, valid_loss: 0.007220047512091697
# SEED: 42, FOLD: 0, EPOCH: 19, train_loss: 0.006637151563717495
# SEED: 42, FOLD: 0, EPOCH: 19, valid_loss: 0.007202673589345068
# SEED: 42, FOLD: 0, EPOCH: 20, train_loss: 0.0059837575251122516
# SEED: 42, FOLD: 0, EPOCH: 20, valid_loss: 0.007227945527993143
# SEED: 42, FOLD: 0, EPOCH: 21, train_loss: 0.005580334878228858
# SEED: 42, FOLD: 0, EPOCH: 21, valid_loss: 0.007775166467763483
# SEED: 42, FOLD: 0, EPOCH: 22, train_loss: 0.0052401298090029936
# SEED: 42, FOLD: 0, EPOCH: 22, valid_loss: 0.0069728997745551165
# SEED: 42, FOLD: 0, EPOCH: 23, train_loss: 0.004804838564386274
# SEED: 42, FOLD: 0, EPOCH: 23, valid_loss: 0.007478154241107404
# SEED: 42, FOLD: 0, EPOCH: 24, train_loss: 0.004446525237567368
# SEED: 42, FOLD: 0, EPOCH: 24, valid_loss: 0.00736766807269305
# SEED: 42, FOLD: 0, EPOCH: 25, train_loss: 0.004315485194211407
# SEED: 42, FOLD: 0, EPOCH: 25, valid_loss: 0.00720626249909401
# SEED: 42, FOLD: 0, EPOCH: 26, train_loss: 0.004097042785843416
# SEED: 42, FOLD: 0, EPOCH: 26, valid_loss: 0.007263271175324917
# SEED: 42, FOLD: 0, EPOCH: 27, train_loss: 0.003998505661175365
# SEED: 42, FOLD: 0, EPOCH: 27, valid_loss: 0.0072841599024832246
# SEED: 42, FOLD: 0, EPOCH: 28, train_loss: 0.0038537166943000693
# SEED: 42, FOLD: 0, EPOCH: 28, valid_loss: 0.007294164353515953
# SEED: 42, FOLD: 0, EPOCH: 29, train_loss: 0.0038928060181008107
# SEED: 42, FOLD: 0, EPOCH: 29, valid_loss: 0.007246979249175638
# SEED: 42, FOLD: 1, EPOCH: 0, train_loss: 0.5804660492101494
# SEED: 42, FOLD: 1, EPOCH: 0, valid_loss: 0.0619471025466919
# SEED: 42, FOLD: 1, EPOCH: 1, train_loss: 0.02230832308885597
# SEED: 42, FOLD: 1, EPOCH: 1, valid_loss: 0.009747587461024523
# SEED: 42, FOLD: 1, EPOCH: 2, train_loss: 0.01451919142308892
# SEED: 42, FOLD: 1, EPOCH: 2, valid_loss: 0.007897512186318636
# SEED: 42, FOLD: 1, EPOCH: 3, train_loss: 0.01364289794028515
# SEED: 42, FOLD: 1, EPOCH: 3, valid_loss: 0.007746540266089142
# SEED: 42, FOLD: 1, EPOCH: 4, train_loss: 0.010692856708528842
# SEED: 42, FOLD: 1, EPOCH: 4, valid_loss: 0.006825756090693176
# SEED: 42, FOLD: 1, EPOCH: 5, train_loss: 0.01008455992872719
# SEED: 42, FOLD: 1, EPOCH: 5, valid_loss: 0.007928998772986234
# SEED: 42, FOLD: 1, EPOCH: 6, train_loss: 0.010972091004721263
# SEED: 42, FOLD: 1, EPOCH: 6, valid_loss: 0.006523954952135682
# SEED: 42, FOLD: 1, EPOCH: 7, train_loss: 0.009166808752976612
# SEED: 42, FOLD: 1, EPOCH: 7, valid_loss: 0.006736130863428116
# SEED: 42, FOLD: 1, EPOCH: 8, train_loss: 0.009542584602980792
# SEED: 42, FOLD: 1, EPOCH: 8, valid_loss: 0.006571714584715664
# SEED: 42, FOLD: 1, EPOCH: 9, train_loss: 0.009094036954017927
# SEED: 42, FOLD: 1, EPOCH: 9, valid_loss: 0.006445672241970897
# SEED: 42, FOLD: 1, EPOCH: 10, train_loss: 0.008883480571818595
# SEED: 42, FOLD: 1, EPOCH: 10, valid_loss: 0.007512411382049322
# SEED: 42, FOLD: 1, EPOCH: 11, train_loss: 0.00859667475455675
# SEED: 42, FOLD: 1, EPOCH: 11, valid_loss: 0.006692679151892662
# SEED: 42, FOLD: 1, EPOCH: 12, train_loss: 0.008377649903702898
# SEED: 42, FOLD: 1, EPOCH: 12, valid_loss: 0.006643936985637993
# SEED: 42, FOLD: 1, EPOCH: 13, train_loss: 0.008324359377313937
# SEED: 42, FOLD: 1, EPOCH: 13, valid_loss: 0.007051691319793463
# SEED: 42, FOLD: 1, EPOCH: 14, train_loss: 0.007662270596681707
# SEED: 42, FOLD: 1, EPOCH: 14, valid_loss: 0.006410018925089389
# SEED: 42, FOLD: 1, EPOCH: 15, train_loss: 0.007593317761966566
# SEED: 42, FOLD: 1, EPOCH: 15, valid_loss: 0.006219520065933466
# SEED: 42, FOLD: 1, EPOCH: 16, train_loss: 0.007172057685461275
# SEED: 42, FOLD: 1, EPOCH: 16, valid_loss: 0.006731279257219285
# SEED: 42, FOLD: 1, EPOCH: 17, train_loss: 0.006978731798831703
# SEED: 42, FOLD: 1, EPOCH: 17, valid_loss: 0.006445299058686942
# SEED: 42, FOLD: 1, EPOCH: 18, train_loss: 0.006202221570891284
# SEED: 42, FOLD: 1, EPOCH: 18, valid_loss: 0.006362716029398144
# SEED: 42, FOLD: 1, EPOCH: 19, train_loss: 0.006111908222542328
# SEED: 42, FOLD: 1, EPOCH: 19, valid_loss: 0.0067089681106153876
# SEED: 42, FOLD: 1, EPOCH: 20, train_loss: 0.005515347908054586
# SEED: 42, FOLD: 1, EPOCH: 20, valid_loss: 0.006674989908933639
# SEED: 42, FOLD: 1, EPOCH: 21, train_loss: 0.00507667961333986
# SEED: 42, FOLD: 1, EPOCH: 21, valid_loss: 0.0064602788514457644
# SEED: 42, FOLD: 1, EPOCH: 22, train_loss: 0.004810767938845417
# SEED: 42, FOLD: 1, EPOCH: 22, valid_loss: 0.006914240841288119
# SEED: 42, FOLD: 1, EPOCH: 23, train_loss: 0.004493646166876567
# SEED: 42, FOLD: 1, EPOCH: 23, valid_loss: 0.006369873723015189
# SEED: 42, FOLD: 1, EPOCH: 24, train_loss: 0.004180452358737892
# SEED: 42, FOLD: 1, EPOCH: 24, valid_loss: 0.006568003240972758
# SEED: 42, FOLD: 1, EPOCH: 25, train_loss: 0.00407872528794418
# SEED: 42, FOLD: 1, EPOCH: 25, valid_loss: 0.0065732636023312805
# SEED: 42, FOLD: 1, EPOCH: 26, train_loss: 0.0038425626524654375
# SEED: 42, FOLD: 1, EPOCH: 26, valid_loss: 0.0065586634119972585
# SEED: 42, FOLD: 1, EPOCH: 27, train_loss: 0.0037382209790731164
# SEED: 42, FOLD: 1, EPOCH: 27, valid_loss: 0.006625912149902433
# SEED: 42, FOLD: 1, EPOCH: 28, train_loss: 0.003715181602862011
# SEED: 42, FOLD: 1, EPOCH: 28, valid_loss: 0.0066336691449396315
# SEED: 42, FOLD: 1, EPOCH: 29, train_loss: 0.003636353804419438
# SEED: 42, FOLD: 1, EPOCH: 29, valid_loss: 0.006591755256522447
# SEED: 42, FOLD: 2, EPOCH: 0, train_loss: 0.5834836928921492
# SEED: 42, FOLD: 2, EPOCH: 0, valid_loss: 0.0667775322496891
# SEED: 42, FOLD: 2, EPOCH: 1, train_loss: 0.02355521451365076
# SEED: 42, FOLD: 2, EPOCH: 1, valid_loss: 0.010847250130027533
# SEED: 42, FOLD: 2, EPOCH: 2, train_loss: 0.013827546756258425
# SEED: 42, FOLD: 2, EPOCH: 2, valid_loss: 0.00875732677988708
# SEED: 42, FOLD: 2, EPOCH: 3, train_loss: 0.012491674908455841
# SEED: 42, FOLD: 2, EPOCH: 3, valid_loss: 0.008663849369622768
# SEED: 42, FOLD: 2, EPOCH: 4, train_loss: 0.012329009377403933
# SEED: 42, FOLD: 2, EPOCH: 4, valid_loss: 0.008971400000154972
# SEED: 42, FOLD: 2, EPOCH: 5, train_loss: 0.010794607035460927
# SEED: 42, FOLD: 2, EPOCH: 5, valid_loss: 0.009383316640742123
# SEED: 42, FOLD: 2, EPOCH: 6, train_loss: 0.010239725802600587
# SEED: 42, FOLD: 2, EPOCH: 6, valid_loss: 0.008183081038296222
# SEED: 42, FOLD: 2, EPOCH: 7, train_loss: 0.009517016446813435
# SEED: 42, FOLD: 2, EPOCH: 7, valid_loss: 0.00793632800457999
# SEED: 42, FOLD: 2, EPOCH: 8, train_loss: 0.009537582003771245
# SEED: 42, FOLD: 2, EPOCH: 8, valid_loss: 0.008143852101638913
# SEED: 42, FOLD: 2, EPOCH: 9, train_loss: 0.00901105984107775
# SEED: 42, FOLD: 2, EPOCH: 9, valid_loss: 0.009234822615981101
# SEED: 42, FOLD: 2, EPOCH: 10, train_loss: 0.009287685282579084
# SEED: 42, FOLD: 2, EPOCH: 10, valid_loss: 0.007639660094864667
# SEED: 42, FOLD: 2, EPOCH: 11, train_loss: 0.0084744736276643
# SEED: 42, FOLD: 2, EPOCH: 11, valid_loss: 0.00917010199278593
# SEED: 42, FOLD: 2, EPOCH: 12, train_loss: 0.00859416687550644
# SEED: 42, FOLD: 2, EPOCH: 12, valid_loss: 0.007734264945611358
# SEED: 42, FOLD: 2, EPOCH: 13, train_loss: 0.007946081489616005
# SEED: 42, FOLD: 2, EPOCH: 13, valid_loss: 0.008087564250454307
# SEED: 42, FOLD: 2, EPOCH: 14, train_loss: 0.008364228392336644
# SEED: 42, FOLD: 2, EPOCH: 14, valid_loss: 0.007414939645677805
# SEED: 42, FOLD: 2, EPOCH: 15, train_loss: 0.007945402300454119
# SEED: 42, FOLD: 2, EPOCH: 15, valid_loss: 0.0076112426188774404
# SEED: 42, FOLD: 2, EPOCH: 16, train_loss: 0.007531522470684785
# SEED: 42, FOLD: 2, EPOCH: 16, valid_loss: 0.007439030385576188
# SEED: 42, FOLD: 2, EPOCH: 17, train_loss: 0.00706679461409851
# SEED: 42, FOLD: 2, EPOCH: 17, valid_loss: 0.007398755529429764
# SEED: 42, FOLD: 2, EPOCH: 18, train_loss: 0.0065927026020426325
# SEED: 42, FOLD: 2, EPOCH: 18, valid_loss: 0.007601335430517792
# SEED: 42, FOLD: 2, EPOCH: 19, train_loss: 0.006169867278932005
# SEED: 42, FOLD: 2, EPOCH: 19, valid_loss: 0.007567918845452369
# SEED: 42, FOLD: 2, EPOCH: 20, train_loss: 0.006049492776545943
# SEED: 42, FOLD: 2, EPOCH: 20, valid_loss: 0.007198707703500986
# SEED: 42, FOLD: 2, EPOCH: 21, train_loss: 0.005481600801010622
# SEED: 42, FOLD: 2, EPOCH: 21, valid_loss: 0.007209251339081675
# SEED: 42, FOLD: 2, EPOCH: 22, train_loss: 0.0049691225693491445
# SEED: 42, FOLD: 2, EPOCH: 22, valid_loss: 0.0069718507642392066
# SEED: 42, FOLD: 2, EPOCH: 23, train_loss: 0.004900570380735864
# SEED: 42, FOLD: 2, EPOCH: 23, valid_loss: 0.007169397863326594
# SEED: 42, FOLD: 2, EPOCH: 24, train_loss: 0.004478411658724047
# SEED: 42, FOLD: 2, EPOCH: 24, valid_loss: 0.007228461109334603
# SEED: 42, FOLD: 2, EPOCH: 25, train_loss: 0.004183492786409396
# SEED: 42, FOLD: 2, EPOCH: 25, valid_loss: 0.007113516301615164
# SEED: 42, FOLD: 2, EPOCH: 26, train_loss: 0.003985545493434279
# SEED: 42, FOLD: 2, EPOCH: 26, valid_loss: 0.007366577364737168
# SEED: 42, FOLD: 2, EPOCH: 27, train_loss: 0.0039240071806600505
# SEED: 42, FOLD: 2, EPOCH: 27, valid_loss: 0.007239887086907402
# SEED: 42, FOLD: 2, EPOCH: 28, train_loss: 0.003795229476642142
# SEED: 42, FOLD: 2, EPOCH: 28, valid_loss: 0.0072297755302861335
# SEED: 42, FOLD: 2, EPOCH: 29, train_loss: 0.0037958441257831595
# SEED: 42, FOLD: 2, EPOCH: 29, valid_loss: 0.0073645214026328175
# SEED: 42, FOLD: 3, EPOCH: 0, train_loss: 0.5845111660203155
# SEED: 42, FOLD: 3, EPOCH: 0, valid_loss: 0.07017235159873962
# SEED: 42, FOLD: 3, EPOCH: 1, train_loss: 0.0232420585428675
# SEED: 42, FOLD: 3, EPOCH: 1, valid_loss: 0.01222902949899435
# SEED: 42, FOLD: 3, EPOCH: 2, train_loss: 0.014127458714987754
# SEED: 42, FOLD: 3, EPOCH: 2, valid_loss: 0.010555490758270026
# SEED: 42, FOLD: 3, EPOCH: 3, train_loss: 0.012890173176138782
# SEED: 42, FOLD: 3, EPOCH: 3, valid_loss: 0.009268949618563055
# SEED: 42, FOLD: 3, EPOCH: 4, train_loss: 0.010983735842465543
# SEED: 42, FOLD: 3, EPOCH: 4, valid_loss: 0.00924661616794765
# SEED: 42, FOLD: 3, EPOCH: 5, train_loss: 0.010202495370148904
# SEED: 42, FOLD: 3, EPOCH: 5, valid_loss: 0.008782932288013398
# SEED: 42, FOLD: 3, EPOCH: 6, train_loss: 0.009518968839464443
# SEED: 42, FOLD: 3, EPOCH: 6, valid_loss: 0.008763835029676557
# SEED: 42, FOLD: 3, EPOCH: 7, train_loss: 0.008771434112699057
# SEED: 42, FOLD: 3, EPOCH: 7, valid_loss: 0.009063213309273123
# SEED: 42, FOLD: 3, EPOCH: 8, train_loss: 0.009213713029412185
# SEED: 42, FOLD: 3, EPOCH: 8, valid_loss: 0.008559140674769879
# SEED: 42, FOLD: 3, EPOCH: 9, train_loss: 0.00884982665246796
# SEED: 42, FOLD: 3, EPOCH: 9, valid_loss: 0.008279462340287863
# SEED: 42, FOLD: 3, EPOCH: 10, train_loss: 0.00907721796522842
# SEED: 42, FOLD: 3, EPOCH: 10, valid_loss: 0.00847843797877431
# SEED: 42, FOLD: 3, EPOCH: 11, train_loss: 0.008503334680698863
# SEED: 42, FOLD: 3, EPOCH: 11, valid_loss: 0.008220927389338613
# SEED: 42, FOLD: 3, EPOCH: 12, train_loss: 0.008338724735009224
# SEED: 42, FOLD: 3, EPOCH: 12, valid_loss: 0.009023125357925892
# SEED: 42, FOLD: 3, EPOCH: 13, train_loss: 0.007921719421524883
# SEED: 42, FOLD: 3, EPOCH: 13, valid_loss: 0.008262780671939253
# SEED: 42, FOLD: 3, EPOCH: 14, train_loss: 0.00819268187533329
# SEED: 42, FOLD: 3, EPOCH: 14, valid_loss: 0.008619398036971688
# SEED: 42, FOLD: 3, EPOCH: 15, train_loss: 0.007762704602106899
# SEED: 42, FOLD: 3, EPOCH: 15, valid_loss: 0.008691830318421126
# SEED: 42, FOLD: 3, EPOCH: 16, train_loss: 0.007069358127001597
# SEED: 42, FOLD: 3, EPOCH: 16, valid_loss: 0.008282705759629607
# SEED: 42, FOLD: 3, EPOCH: 17, train_loss: 0.007125852271585035
# SEED: 42, FOLD: 3, EPOCH: 17, valid_loss: 0.008202259796671569
# SEED: 42, FOLD: 3, EPOCH: 18, train_loss: 0.006806489677314146
# SEED: 42, FOLD: 3, EPOCH: 18, valid_loss: 0.008492223965004087
# SEED: 42, FOLD: 3, EPOCH: 19, train_loss: 0.006452499736784672
# SEED: 42, FOLD: 3, EPOCH: 19, valid_loss: 0.007875123945996165
# SEED: 42, FOLD: 3, EPOCH: 20, train_loss: 0.005694592522051768
# SEED: 42, FOLD: 3, EPOCH: 20, valid_loss: 0.008481640135869384
# SEED: 42, FOLD: 3, EPOCH: 21, train_loss: 0.005481372335545567
# SEED: 42, FOLD: 3, EPOCH: 21, valid_loss: 0.008252198668196797
# SEED: 42, FOLD: 3, EPOCH: 22, train_loss: 0.005044382292029708
# SEED: 42, FOLD: 3, EPOCH: 22, valid_loss: 0.008329111859202385
# SEED: 42, FOLD: 3, EPOCH: 23, train_loss: 0.004814850142681781
# SEED: 42, FOLD: 3, EPOCH: 23, valid_loss: 0.008417508983984589
# SEED: 42, FOLD: 3, EPOCH: 24, train_loss: 0.004405178878849157
# SEED: 42, FOLD: 3, EPOCH: 24, valid_loss: 0.008221734692342579
# SEED: 42, FOLD: 3, EPOCH: 25, train_loss: 0.004208708470243783
# SEED: 42, FOLD: 3, EPOCH: 25, valid_loss: 0.008208352676592767
# SEED: 42, FOLD: 3, EPOCH: 26, train_loss: 0.004109377632247043
# SEED: 42, FOLD: 3, EPOCH: 26, valid_loss: 0.00844141368754208
# SEED: 42, FOLD: 3, EPOCH: 27, train_loss: 0.003975112859134366
# SEED: 42, FOLD: 3, EPOCH: 27, valid_loss: 0.008320494832005351
# SEED: 42, FOLD: 3, EPOCH: 28, train_loss: 0.0037847797269140986
# SEED: 42, FOLD: 3, EPOCH: 28, valid_loss: 0.008202136401087046
# SEED: 42, FOLD: 3, EPOCH: 29, train_loss: 0.003755087927807452
# SEED: 42, FOLD: 3, EPOCH: 29, valid_loss: 0.008273907550610603
# SEED: 42, FOLD: 4, EPOCH: 0, train_loss: 0.5765456861886037
# SEED: 42, FOLD: 4, EPOCH: 0, valid_loss: 0.05698416128754616
# SEED: 42, FOLD: 4, EPOCH: 1, train_loss: 0.02393967191036157
# SEED: 42, FOLD: 4, EPOCH: 1, valid_loss: 0.014158040396869182
# SEED: 42, FOLD: 4, EPOCH: 2, train_loss: 0.014935863758659079
# SEED: 42, FOLD: 4, EPOCH: 2, valid_loss: 0.010101426243782043
# SEED: 42, FOLD: 4, EPOCH: 3, train_loss: 0.01265906472373627
# SEED: 42, FOLD: 4, EPOCH: 3, valid_loss: 0.009986667074263095
# SEED: 42, FOLD: 4, EPOCH: 4, train_loss: 0.011151867408660195
# SEED: 42, FOLD: 4, EPOCH: 4, valid_loss: 0.008580545745790005
# SEED: 42, FOLD: 4, EPOCH: 5, train_loss: 0.010317485280601042
# SEED: 42, FOLD: 4, EPOCH: 5, valid_loss: 0.008259513312950731
# SEED: 42, FOLD: 4, EPOCH: 6, train_loss: 0.009986012000400496
# SEED: 42, FOLD: 4, EPOCH: 6, valid_loss: 0.008066239398904145
# SEED: 42, FOLD: 4, EPOCH: 7, train_loss: 0.0095475516456249
# SEED: 42, FOLD: 4, EPOCH: 7, valid_loss: 0.007303002490662038
# SEED: 42, FOLD: 4, EPOCH: 8, train_loss: 0.009078471563427018
# SEED: 42, FOLD: 4, EPOCH: 8, valid_loss: 0.007444541146978736
# SEED: 42, FOLD: 4, EPOCH: 9, train_loss: 0.008912897076407056
# SEED: 42, FOLD: 4, EPOCH: 9, valid_loss: 0.00763524180278182
# SEED: 42, FOLD: 4, EPOCH: 10, train_loss: 0.009249161279500545
# SEED: 42, FOLD: 4, EPOCH: 10, valid_loss: 0.00826179473195225
# SEED: 42, FOLD: 4, EPOCH: 11, train_loss: 0.008669676137201134
# SEED: 42, FOLD: 4, EPOCH: 11, valid_loss: 0.00781558372080326
# SEED: 42, FOLD: 4, EPOCH: 12, train_loss: 0.00850292165497584
# SEED: 42, FOLD: 4, EPOCH: 12, valid_loss: 0.007860260913148523
# SEED: 42, FOLD: 4, EPOCH: 13, train_loss: 0.008627570760087902
# SEED: 42, FOLD: 4, EPOCH: 13, valid_loss: 0.00735881607979536
# SEED: 42, FOLD: 4, EPOCH: 14, train_loss: 0.008172335888759619
# SEED: 42, FOLD: 4, EPOCH: 14, valid_loss: 0.007552108108066022
# SEED: 42, FOLD: 4, EPOCH: 15, train_loss: 0.007887384160516821
# SEED: 42, FOLD: 4, EPOCH: 15, valid_loss: 0.00715898287948221
# SEED: 42, FOLD: 4, EPOCH: 16, train_loss: 0.007367989955926124
# SEED: 42, FOLD: 4, EPOCH: 16, valid_loss: 0.007575293853878975
# SEED: 42, FOLD: 4, EPOCH: 17, train_loss: 0.007276135175267146
# SEED: 42, FOLD: 4, EPOCH: 17, valid_loss: 0.007054031733423472
# SEED: 42, FOLD: 4, EPOCH: 18, train_loss: 0.0068144903686151006
# SEED: 42, FOLD: 4, EPOCH: 18, valid_loss: 0.00742904297541827
# SEED: 42, FOLD: 4, EPOCH: 19, train_loss: 0.006517863141841629
# SEED: 42, FOLD: 4, EPOCH: 19, valid_loss: 0.0076283704256638885
# SEED: 42, FOLD: 4, EPOCH: 20, train_loss: 0.005989218609040083
# SEED: 42, FOLD: 4, EPOCH: 20, valid_loss: 0.006877003647387028
# SEED: 42, FOLD: 4, EPOCH: 21, train_loss: 0.005464296377751799
# SEED: 42, FOLD: 4, EPOCH: 21, valid_loss: 0.007440965953283012
# SEED: 42, FOLD: 4, EPOCH: 22, train_loss: 0.005095803717366692
# SEED: 42, FOLD: 4, EPOCH: 22, valid_loss: 0.007232471001334489
# SEED: 42, FOLD: 4, EPOCH: 23, train_loss: 0.004654463057463266
# SEED: 42, FOLD: 4, EPOCH: 23, valid_loss: 0.007273717795033008
# SEED: 42, FOLD: 4, EPOCH: 24, train_loss: 0.004524439573287964
# SEED: 42, FOLD: 4, EPOCH: 24, valid_loss: 0.007132088174112141
# SEED: 42, FOLD: 4, EPOCH: 25, train_loss: 0.0042229144672426035
# SEED: 42, FOLD: 4, EPOCH: 25, valid_loss: 0.007234014633577317
# SEED: 42, FOLD: 4, EPOCH: 26, train_loss: 0.004013217697363524
# SEED: 42, FOLD: 4, EPOCH: 26, valid_loss: 0.007157318072859198
# SEED: 42, FOLD: 4, EPOCH: 27, train_loss: 0.003911476563282159
# SEED: 42, FOLD: 4, EPOCH: 27, valid_loss: 0.0072474550292827185
# SEED: 42, FOLD: 4, EPOCH: 28, train_loss: 0.0037805994095116043
# SEED: 42, FOLD: 4, EPOCH: 28, valid_loss: 0.0072589591634459796
# SEED: 42, FOLD: 4, EPOCH: 29, train_loss: 0.003849650882057795
# SEED: 42, FOLD: 4, EPOCH: 29, valid_loss: 0.0073300502123311165
# SEED: 42, FOLD: 5, EPOCH: 0, train_loss: 0.5784907561479783
# SEED: 42, FOLD: 5, EPOCH: 0, valid_loss: 0.06059606805443764
# SEED: 42, FOLD: 5, EPOCH: 1, train_loss: 0.0239131133021394
# SEED: 42, FOLD: 5, EPOCH: 1, valid_loss: 0.014079585559666158
# SEED: 42, FOLD: 5, EPOCH: 2, train_loss: 0.01380713593822961
# SEED: 42, FOLD: 5, EPOCH: 2, valid_loss: 0.010163190462626516
# SEED: 42, FOLD: 5, EPOCH: 3, train_loss: 0.013023790494747917
# SEED: 42, FOLD: 5, EPOCH: 3, valid_loss: 0.01081311452202499
# SEED: 42, FOLD: 5, EPOCH: 4, train_loss: 0.011633861231852043
# SEED: 42, FOLD: 5, EPOCH: 4, valid_loss: 0.009402988320216537
# SEED: 42, FOLD: 5, EPOCH: 5, train_loss: 0.010332321347415347
# SEED: 42, FOLD: 5, EPOCH: 5, valid_loss: 0.008724762978963553
# SEED: 42, FOLD: 5, EPOCH: 6, train_loss: 0.010060063715339924
# SEED: 42, FOLD: 5, EPOCH: 6, valid_loss: 0.008410188453271985
# SEED: 42, FOLD: 5, EPOCH: 7, train_loss: 0.009328917798199722
# SEED: 42, FOLD: 5, EPOCH: 7, valid_loss: 0.008520372775383294
# SEED: 42, FOLD: 5, EPOCH: 8, train_loss: 0.009050110312254757
# SEED: 42, FOLD: 5, EPOCH: 8, valid_loss: 0.009007575185969473
# SEED: 42, FOLD: 5, EPOCH: 9, train_loss: 0.008727473477661913
# SEED: 42, FOLD: 5, EPOCH: 9, valid_loss: 0.008150078812614083
# SEED: 42, FOLD: 5, EPOCH: 10, train_loss: 0.008853081515578388
# SEED: 42, FOLD: 5, EPOCH: 10, valid_loss: 0.008739114422351122
# SEED: 42, FOLD: 5, EPOCH: 11, train_loss: 0.009061026754377245
# SEED: 42, FOLD: 5, EPOCH: 11, valid_loss: 0.008929623821750284
# SEED: 42, FOLD: 5, EPOCH: 12, train_loss: 0.008521918204239233
# SEED: 42, FOLD: 5, EPOCH: 12, valid_loss: 0.00890740753384307
# SEED: 42, FOLD: 5, EPOCH: 13, train_loss: 0.008238325598744713
# SEED: 42, FOLD: 5, EPOCH: 13, valid_loss: 0.008495676354505122
# SEED: 42, FOLD: 5, EPOCH: 14, train_loss: 0.007920614711395433
# SEED: 42, FOLD: 5, EPOCH: 14, valid_loss: 0.007883238843642176
# SEED: 42, FOLD: 5, EPOCH: 15, train_loss: 0.007562813261954658
# SEED: 42, FOLD: 5, EPOCH: 15, valid_loss: 0.008576259387191386
# SEED: 42, FOLD: 5, EPOCH: 16, train_loss: 0.007465444513134101
# SEED: 42, FOLD: 5, EPOCH: 16, valid_loss: 0.008623856818303466
# SEED: 42, FOLD: 5, EPOCH: 17, train_loss: 0.0070319568823870955
# SEED: 42, FOLD: 5, EPOCH: 17, valid_loss: 0.008592696879059076
# SEED: 42, FOLD: 5, EPOCH: 18, train_loss: 0.006835938963506903
# SEED: 42, FOLD: 5, EPOCH: 18, valid_loss: 0.00872051065089181
# SEED: 42, FOLD: 5, EPOCH: 19, train_loss: 0.006239751052922335
# SEED: 42, FOLD: 5, EPOCH: 19, valid_loss: 0.009191870572976768
# SEED: 42, FOLD: 5, EPOCH: 20, train_loss: 0.005783879666962997
# SEED: 42, FOLD: 5, EPOCH: 20, valid_loss: 0.008850245776120574
# SEED: 42, FOLD: 5, EPOCH: 21, train_loss: 0.005416024330572612
# SEED: 42, FOLD: 5, EPOCH: 21, valid_loss: 0.009099291393067688
# SEED: 42, FOLD: 5, EPOCH: 22, train_loss: 0.004969705981170746
# SEED: 42, FOLD: 5, EPOCH: 22, valid_loss: 0.008748337073484436
# SEED: 42, FOLD: 5, EPOCH: 23, train_loss: 0.00469524609273439
# SEED: 42, FOLD: 5, EPOCH: 23, valid_loss: 0.009086465103318914
# SEED: 42, FOLD: 5, EPOCH: 24, train_loss: 0.004362348932772875
# SEED: 42, FOLD: 5, EPOCH: 24, valid_loss: 0.008736454963218421
# SEED: 42, FOLD: 5, EPOCH: 25, train_loss: 0.004142876614683441
# SEED: 42, FOLD: 5, EPOCH: 25, valid_loss: 0.008961993617704138
# SEED: 42, FOLD: 5, EPOCH: 26, train_loss: 0.003997856073182862
# SEED: 42, FOLD: 5, EPOCH: 26, valid_loss: 0.009160679024644196
# SEED: 42, FOLD: 5, EPOCH: 27, train_loss: 0.0038345932206582454
# SEED: 42, FOLD: 5, EPOCH: 27, valid_loss: 0.008996992704924196
# SEED: 42, FOLD: 5, EPOCH: 28, train_loss: 0.003829827845780825
# SEED: 42, FOLD: 5, EPOCH: 28, valid_loss: 0.009137595783686265
# SEED: 42, FOLD: 5, EPOCH: 29, train_loss: 0.003720856355629912
# SEED: 42, FOLD: 5, EPOCH: 29, valid_loss: 0.009131886420072987
# SEED: 42, FOLD: 6, EPOCH: 0, train_loss: 0.5802926031910643
# SEED: 42, FOLD: 6, EPOCH: 0, valid_loss: 0.060291256308555606
# SEED: 42, FOLD: 6, EPOCH: 1, train_loss: 0.02347077470792293
# SEED: 42, FOLD: 6, EPOCH: 1, valid_loss: 0.010938400030136108
# SEED: 42, FOLD: 6, EPOCH: 2, train_loss: 0.014402743343415916
# SEED: 42, FOLD: 6, EPOCH: 2, valid_loss: 0.008554618759080767
# SEED: 42, FOLD: 6, EPOCH: 3, train_loss: 0.012252696970363661
# SEED: 42, FOLD: 6, EPOCH: 3, valid_loss: 0.00815153935458511
# SEED: 42, FOLD: 6, EPOCH: 4, train_loss: 0.011402370075562171
# SEED: 42, FOLD: 6, EPOCH: 4, valid_loss: 0.008036587862297892
# SEED: 42, FOLD: 6, EPOCH: 5, train_loss: 0.010571182724468562
# SEED: 42, FOLD: 6, EPOCH: 5, valid_loss: 0.007420453736558557
# SEED: 42, FOLD: 6, EPOCH: 6, train_loss: 0.010231834095047444
# SEED: 42, FOLD: 6, EPOCH: 6, valid_loss: 0.008012126097455621
# SEED: 42, FOLD: 6, EPOCH: 7, train_loss: 0.01075571647141965
# SEED: 42, FOLD: 6, EPOCH: 7, valid_loss: 0.0071000767080113296
# SEED: 42, FOLD: 6, EPOCH: 8, train_loss: 0.009255576695055783
# SEED: 42, FOLD: 6, EPOCH: 8, valid_loss: 0.007296000425703823
# SEED: 42, FOLD: 6, EPOCH: 9, train_loss: 0.009084672806467735
# SEED: 42, FOLD: 6, EPOCH: 9, valid_loss: 0.008087733397260308
# SEED: 42, FOLD: 6, EPOCH: 10, train_loss: 0.009045044433794358
# SEED: 42, FOLD: 6, EPOCH: 10, valid_loss: 0.007522558541968465
# SEED: 42, FOLD: 6, EPOCH: 11, train_loss: 0.008813593820130238
# SEED: 42, FOLD: 6, EPOCH: 11, valid_loss: 0.008062523007392883
# SEED: 42, FOLD: 6, EPOCH: 12, train_loss: 0.00868240434068198
# SEED: 42, FOLD: 6, EPOCH: 12, valid_loss: 0.008097894052043557
# SEED: 42, FOLD: 6, EPOCH: 13, train_loss: 0.008446635241259118
# SEED: 42, FOLD: 6, EPOCH: 13, valid_loss: 0.007566213239915669
# SEED: 42, FOLD: 6, EPOCH: 14, train_loss: 0.008122154682570574
# SEED: 42, FOLD: 6, EPOCH: 14, valid_loss: 0.007578170304186642
# SEED: 42, FOLD: 6, EPOCH: 15, train_loss: 0.007920047779865309
# SEED: 42, FOLD: 6, EPOCH: 15, valid_loss: 0.007648045690730214
# SEED: 42, FOLD: 6, EPOCH: 16, train_loss: 0.007341967320677881
# SEED: 42, FOLD: 6, EPOCH: 16, valid_loss: 0.007070216820575297
# SEED: 42, FOLD: 6, EPOCH: 17, train_loss: 0.007210662441176115
# SEED: 42, FOLD: 6, EPOCH: 17, valid_loss: 0.007747182415332645
# SEED: 42, FOLD: 6, EPOCH: 18, train_loss: 0.006996640574415119
# SEED: 42, FOLD: 6, EPOCH: 18, valid_loss: 0.006865438090171665
# SEED: 42, FOLD: 6, EPOCH: 19, train_loss: 0.006229832727259316
# SEED: 42, FOLD: 6, EPOCH: 19, valid_loss: 0.006967622092925012
# SEED: 42, FOLD: 6, EPOCH: 20, train_loss: 0.005912479201686524
# SEED: 42, FOLD: 6, EPOCH: 20, valid_loss: 0.007132053175009787
# SEED: 42, FOLD: 6, EPOCH: 21, train_loss: 0.005319761291311002
# SEED: 42, FOLD: 6, EPOCH: 21, valid_loss: 0.007005052496679127
# SEED: 42, FOLD: 6, EPOCH: 22, train_loss: 0.005091519917038326
# SEED: 42, FOLD: 6, EPOCH: 22, valid_loss: 0.007655846930574626
# SEED: 42, FOLD: 6, EPOCH: 23, train_loss: 0.004711558301077813
# SEED: 42, FOLD: 6, EPOCH: 23, valid_loss: 0.00719410435995087
# SEED: 42, FOLD: 6, EPOCH: 24, train_loss: 0.004471184064944585
# SEED: 42, FOLD: 6, EPOCH: 24, valid_loss: 0.007417871272191405
# SEED: 42, FOLD: 6, EPOCH: 25, train_loss: 0.00411226224394984
# SEED: 42, FOLD: 6, EPOCH: 25, valid_loss: 0.007342081796377897
# SEED: 42, FOLD: 6, EPOCH: 26, train_loss: 0.004067991153799555
# SEED: 42, FOLD: 6, EPOCH: 26, valid_loss: 0.00767126634134911
# SEED: 42, FOLD: 6, EPOCH: 27, train_loss: 0.003889957037405903
# SEED: 42, FOLD: 6, EPOCH: 27, valid_loss: 0.007235940843820572
# SEED: 42, FOLD: 6, EPOCH: 28, train_loss: 0.003861665690862605
# SEED: 42, FOLD: 6, EPOCH: 28, valid_loss: 0.007405245609115809
# SEED: 42, FOLD: 6, EPOCH: 29, train_loss: 0.0037974861805282886
# SEED: 42, FOLD: 6, EPOCH: 29, valid_loss: 0.007359922315226868

# %% [markdown]
# # Model A Outputs
# Model A will output features to be used as input features for the train and test sets of Model B

# %%
# Training Features with sig_id column
Model_A_to_Model_B_train = Model_A_validation_predictions
Model_A_to_Model_B_train.columns = ['f-model_A-' + col if (col != 'sig_id') else col for col in Model_A_to_Model_B_train.columns]
# Test Features
Model_A_to_Model_B_test = Model_A_test_predictions
Model_A_to_Model_B_test.columns = ['f-model_A-' + col if (col != 'sig_id') else col for col in Model_A_to_Model_B_test.columns]

# %% [markdown]
# ### Use columns with highest correlation (from unchanged target file)

# %%
nonzero_targets_df = targets_nonscored.drop('sig_id', axis=1).loc[:, (targets_nonscored.drop('sig_id', axis=1).sum() > 0).values]
corr_mtx = nonzero_targets_df.corr()
corr_map = corr_mtx[corr_mtx>=.7]
corr_map[corr_map == 1] = np.nan
# Columns that contain high correlation
corr_cols = corr_map.columns[(corr_map.sum(axis=1) >0).values]

temp_corr_cols = ['f-model_A-' + col for col in corr_cols]

print(f"Number of Columns kept from Model A based on high Correlations {len(corr_cols)}")

Model_A_to_Model_B_train = Model_A_to_Model_B_train[['sig_id'] + temp_corr_cols]
Model_A_to_Model_B_test = Model_A_to_Model_B_test[['sig_id'] + temp_corr_cols]

# %% [markdown]
# ### Plot Validation Loss by Fold

# %%
# Plot the validation loss for each fold over the epochs
# valid_loss_array is an array of the validaiton loss for each fold for each epoch
fold_names = [f"Fold_{fold}" for fold in range(NFOLDS)]
val_loss_df = pd.DataFrame(data=valid_loss_array, columns=fold_names)
p = sns.lineplot(data=val_loss_df, dashes=False)
p.set(ylim=(0.003, 0.01))
# Out:
# [(0.004, 0.005)]

# %% [markdown]
# ### Input for Model B
# Model B is trained to predict the <b>scored</b> targets.

# %%
# List of seeds to run over.
# SEEDS = [42]

# list of target/feature column names - should be 206 targets of them
target_columns = target_cols
feature_columns = [c for c in folds.columns if c.startswith('f-')]

# training x and kfold column. Contains 'sig_id' column
X_train = folds[['sig_id'] + feature_columns + ['kfold']]
X_train = X_train.merge(Model_A_to_Model_B_train, on='sig_id', how='left')

y_train = folds[['sig_id'] + target_columns]

# test data. Includes 'sig_id' and features, no target columns or kfold
X_test = test.copy()
X_test = X_test.merge(Model_A_to_Model_B_test, on='sig_id', how='left')

# redeclaring the feature columns now that I have modified the input sets for train/test. Not the cleanest.
feature_columns = [c for c in X_train.columns if c.startswith('f-')]

# %%
# This chunk is just putting a wrapper around the main training function 'run_k_fold'
# To allow many SEEDs to be tested and averaged at once.

oof = np.zeros((X_train.shape[0], len(target_columns)))
predictions = np.zeros((len(X_test), len(target_columns)))
valid_loss_array = np.zeros((HyperParams["EPOCHS"], HyperParams["NFOLDS"]))

for seed in SEEDS:
    
    oof_, predictions_ = run_k_fold(X_train.copy(), y_train.copy(), X_test.copy(), feature_columns, target_columns, HyperParams, seed)
    oof += oof_ / len(SEEDS)
    predictions += predictions_ / len(SEEDS)

# Make new outputs later
validation_predictions = X_train[['sig_id']]
validation_predictions[target_columns] = oof
test_predictions = X_test[['sig_id']]
test_predictions[target_columns] = predictions
# Out:
#  Number of OHE columns added: 5
#  Number of OHE columns added: 5
# SEED: 42, FOLD: 0, EPOCH: 0, train_loss: 0.5846260272625352
# SEED: 42, FOLD: 0, EPOCH: 0, valid_loss: 0.05639411747455597
# SEED: 42, FOLD: 0, EPOCH: 1, train_loss: 0.027617088614069685
# SEED: 42, FOLD: 0, EPOCH: 1, valid_loss: 0.020330577939748764
# SEED: 42, FOLD: 0, EPOCH: 2, train_loss: 0.021722019428298586
# SEED: 42, FOLD: 0, EPOCH: 2, valid_loss: 0.018408135697245597
# SEED: 42, FOLD: 0, EPOCH: 3, train_loss: 0.020607246972975276
# SEED: 42, FOLD: 0, EPOCH: 3, valid_loss: 0.017723437249660492
# SEED: 42, FOLD: 0, EPOCH: 4, train_loss: 0.020164598007591402
# SEED: 42, FOLD: 0, EPOCH: 4, valid_loss: 0.01763448029756546
# SEED: 42, FOLD: 0, EPOCH: 5, train_loss: 0.01957577465697616
# SEED: 42, FOLD: 0, EPOCH: 5, valid_loss: 0.017297732047736644
# SEED: 42, FOLD: 0, EPOCH: 6, train_loss: 0.019417421208048354
# SEED: 42, FOLD: 0, EPOCH: 6, valid_loss: 0.01749896749854088
# SEED: 42, FOLD: 0, EPOCH: 7, train_loss: 0.01927200994980173
# SEED: 42, FOLD: 0, EPOCH: 7, valid_loss: 0.017225363925099373
# SEED: 42, FOLD: 0, EPOCH: 8, train_loss: 0.01934803823376594
# SEED: 42, FOLD: 0, EPOCH: 8, valid_loss: 0.017382496148347856
# SEED: 42, FOLD: 0, EPOCH: 9, train_loss: 0.019282829029118122
# SEED: 42, FOLD: 0, EPOCH: 9, valid_loss: 0.01706222362816334
# SEED: 42, FOLD: 0, EPOCH: 10, train_loss: 0.019309085914168227
# SEED: 42, FOLD: 0, EPOCH: 10, valid_loss: 0.017248847112059592
# SEED: 42, FOLD: 0, EPOCH: 11, train_loss: 0.019282838659120255
# SEED: 42, FOLD: 0, EPOCH: 11, valid_loss: 0.017156973257660867
# SEED: 42, FOLD: 0, EPOCH: 12, train_loss: 0.019313477968074838
# SEED: 42, FOLD: 0, EPOCH: 12, valid_loss: 0.01715772345662117
# SEED: 42, FOLD: 0, EPOCH: 13, train_loss: 0.01925493999808824
# SEED: 42, FOLD: 0, EPOCH: 13, valid_loss: 0.017199069894850254
# SEED: 42, FOLD: 0, EPOCH: 14, train_loss: 0.01918970916394879
# SEED: 42, FOLD: 0, EPOCH: 14, valid_loss: 0.01710199937224388
# SEED: 42, FOLD: 0, EPOCH: 15, train_loss: 0.01915691191089802
# SEED: 42, FOLD: 0, EPOCH: 15, valid_loss: 0.017074668295681477
# SEED: 42, FOLD: 0, EPOCH: 16, train_loss: 0.01909833965937094
# SEED: 42, FOLD: 0, EPOCH: 16, valid_loss: 0.017092920579016208
# SEED: 42, FOLD: 0, EPOCH: 17, train_loss: 0.019027175559174447
# SEED: 42, FOLD: 0, EPOCH: 17, valid_loss: 0.01706783227622509
# SEED: 42, FOLD: 0, EPOCH: 18, train_loss: 0.018858677245118992
# SEED: 42, FOLD: 0, EPOCH: 18, valid_loss: 0.01687721408903599
# SEED: 42, FOLD: 0, EPOCH: 19, train_loss: 0.018798724893911354
# SEED: 42, FOLD: 0, EPOCH: 19, valid_loss: 0.01679759256541729
# SEED: 42, FOLD: 0, EPOCH: 20, train_loss: 0.018627180318747247
# SEED: 42, FOLD: 0, EPOCH: 20, valid_loss: 0.016799494549632074
# SEED: 42, FOLD: 0, EPOCH: 21, train_loss: 0.01844377552165466
# SEED: 42, FOLD: 0, EPOCH: 21, valid_loss: 0.01654650140553713
# SEED: 42, FOLD: 0, EPOCH: 22, train_loss: 0.018235683567872665
# SEED: 42, FOLD: 0, EPOCH: 22, valid_loss: 0.016439884454011917
# SEED: 42, FOLD: 0, EPOCH: 23, train_loss: 0.01800921982547053
# SEED: 42, FOLD: 0, EPOCH: 23, valid_loss: 0.016415289863944055
# SEED: 42, FOLD: 0, EPOCH: 24, train_loss: 0.01772783673210006
# SEED: 42, FOLD: 0, EPOCH: 24, valid_loss: 0.016222236938774587
# SEED: 42, FOLD: 0, EPOCH: 25, train_loss: 0.017380779786478905
# SEED: 42, FOLD: 0, EPOCH: 25, valid_loss: 0.016168128214776516
# SEED: 42, FOLD: 0, EPOCH: 26, train_loss: 0.017056294419124825
# SEED: 42, FOLD: 0, EPOCH: 26, valid_loss: 0.01607927855104208
# SEED: 42, FOLD: 0, EPOCH: 27, train_loss: 0.01676321754447457
# SEED: 42, FOLD: 0, EPOCH: 27, valid_loss: 0.016013222560286523
# SEED: 42, FOLD: 0, EPOCH: 28, train_loss: 0.016530295105359586
# SEED: 42, FOLD: 0, EPOCH: 28, valid_loss: 0.015993888080120085
# SEED: 42, FOLD: 0, EPOCH: 29, train_loss: 0.0164488173552415
# SEED: 42, FOLD: 0, EPOCH: 29, valid_loss: 0.016002252623438837
# SEED: 42, FOLD: 1, EPOCH: 0, train_loss: 0.5818226247721788
# SEED: 42, FOLD: 1, EPOCH: 0, valid_loss: 0.05400950446724892
# SEED: 42, FOLD: 1, EPOCH: 1, train_loss: 0.026854018091547246
# SEED: 42, FOLD: 1, EPOCH: 1, valid_loss: 0.019547958374023438
# SEED: 42, FOLD: 1, EPOCH: 2, train_loss: 0.021440802104010875
# SEED: 42, FOLD: 1, EPOCH: 2, valid_loss: 0.018364933282136918
# SEED: 42, FOLD: 1, EPOCH: 3, train_loss: 0.02049569116563213
# SEED: 42, FOLD: 1, EPOCH: 3, valid_loss: 0.017619597725570202
# SEED: 42, FOLD: 1, EPOCH: 4, train_loss: 0.019916660158711227
# SEED: 42, FOLD: 1, EPOCH: 4, valid_loss: 0.017035677917301654
# SEED: 42, FOLD: 1, EPOCH: 5, train_loss: 0.01959516519845343
# SEED: 42, FOLD: 1, EPOCH: 5, valid_loss: 0.0170731233432889
# SEED: 42, FOLD: 1, EPOCH: 6, train_loss: 0.019536609742410328
# SEED: 42, FOLD: 1, EPOCH: 6, valid_loss: 0.01695739958435297
# SEED: 42, FOLD: 1, EPOCH: 7, train_loss: 0.01939675586969674
# SEED: 42, FOLD: 1, EPOCH: 7, valid_loss: 0.017053482495248316
# SEED: 42, FOLD: 1, EPOCH: 8, train_loss: 0.019333174382494826
# SEED: 42, FOLD: 1, EPOCH: 8, valid_loss: 0.01705675695091486
# SEED: 42, FOLD: 1, EPOCH: 9, train_loss: 0.019270237763317263
# SEED: 42, FOLD: 1, EPOCH: 9, valid_loss: 0.0169855809956789
# SEED: 42, FOLD: 1, EPOCH: 10, train_loss: 0.019271353817209094
# SEED: 42, FOLD: 1, EPOCH: 10, valid_loss: 0.01692632623016834
# SEED: 42, FOLD: 1, EPOCH: 11, train_loss: 0.019225686915269515
# SEED: 42, FOLD: 1, EPOCH: 11, valid_loss: 0.017057423815131187
# SEED: 42, FOLD: 1, EPOCH: 12, train_loss: 0.019195539040528998
# SEED: 42, FOLD: 1, EPOCH: 12, valid_loss: 0.01694205470383167
# SEED: 42, FOLD: 1, EPOCH: 13, train_loss: 0.019199216218829966
# SEED: 42, FOLD: 1, EPOCH: 13, valid_loss: 0.016763767786324026
# SEED: 42, FOLD: 1, EPOCH: 14, train_loss: 0.019016147926956616
# SEED: 42, FOLD: 1, EPOCH: 14, valid_loss: 0.01689943939447403
# SEED: 42, FOLD: 1, EPOCH: 15, train_loss: 0.019037171007216382
# SEED: 42, FOLD: 1, EPOCH: 15, valid_loss: 0.016688588708639145
# SEED: 42, FOLD: 1, EPOCH: 16, train_loss: 0.018975726107046717
# SEED: 42, FOLD: 1, EPOCH: 16, valid_loss: 0.016753302738070488
# SEED: 42, FOLD: 1, EPOCH: 17, train_loss: 0.018887062943508837
# SEED: 42, FOLD: 1, EPOCH: 17, valid_loss: 0.016638773195445537
# SEED: 42, FOLD: 1, EPOCH: 18, train_loss: 0.01877228659736056
# SEED: 42, FOLD: 1, EPOCH: 18, valid_loss: 0.016640742123126984
# SEED: 42, FOLD: 1, EPOCH: 19, train_loss: 0.018635536550360474
# SEED: 42, FOLD: 1, EPOCH: 19, valid_loss: 0.016428116969764234
# SEED: 42, FOLD: 1, EPOCH: 20, train_loss: 0.018546102321421613
# SEED: 42, FOLD: 1, EPOCH: 20, valid_loss: 0.016393668353557586
# SEED: 42, FOLD: 1, EPOCH: 21, train_loss: 0.01823619596634795
# SEED: 42, FOLD: 1, EPOCH: 21, valid_loss: 0.01630352783948183
# SEED: 42, FOLD: 1, EPOCH: 22, train_loss: 0.018060614475283492
# SEED: 42, FOLD: 1, EPOCH: 22, valid_loss: 0.016133535876870154
# SEED: 42, FOLD: 1, EPOCH: 23, train_loss: 0.017813181865732282
# SEED: 42, FOLD: 1, EPOCH: 23, valid_loss: 0.016007373481988905
# SEED: 42, FOLD: 1, EPOCH: 24, train_loss: 0.017497564875045602
# SEED: 42, FOLD: 1, EPOCH: 24, valid_loss: 0.01593778096139431
# SEED: 42, FOLD: 1, EPOCH: 25, train_loss: 0.017206308907087967
# SEED: 42, FOLD: 1, EPOCH: 25, valid_loss: 0.015888554379343986
# SEED: 42, FOLD: 1, EPOCH: 26, train_loss: 0.016821619154898083
# SEED: 42, FOLD: 1, EPOCH: 26, valid_loss: 0.01575866334140301
# SEED: 42, FOLD: 1, EPOCH: 27, train_loss: 0.016568460628440997
# SEED: 42, FOLD: 1, EPOCH: 27, valid_loss: 0.01574015013873577
# SEED: 42, FOLD: 1, EPOCH: 28, train_loss: 0.016374059034143986
# SEED: 42, FOLD: 1, EPOCH: 28, valid_loss: 0.015714328922331332
# SEED: 42, FOLD: 1, EPOCH: 29, train_loss: 0.01630096288309211
# SEED: 42, FOLD: 1, EPOCH: 29, valid_loss: 0.01569758489727974
# SEED: 42, FOLD: 2, EPOCH: 0, train_loss: 0.5845618413976666
# SEED: 42, FOLD: 2, EPOCH: 0, valid_loss: 0.053309541940689084
# SEED: 42, FOLD: 2, EPOCH: 1, train_loss: 0.027459332364655677
# SEED: 42, FOLD: 2, EPOCH: 1, valid_loss: 0.020000747218728066
# SEED: 42, FOLD: 2, EPOCH: 2, train_loss: 0.02151795773177731
# SEED: 42, FOLD: 2, EPOCH: 2, valid_loss: 0.01864736832678318
# SEED: 42, FOLD: 2, EPOCH: 3, train_loss: 0.020609722542418104
# SEED: 42, FOLD: 2, EPOCH: 3, valid_loss: 0.01798573851585388
# SEED: 42, FOLD: 2, EPOCH: 4, train_loss: 0.01999202550572603
# SEED: 42, FOLD: 2, EPOCH: 4, valid_loss: 0.01736466333270073
# SEED: 42, FOLD: 2, EPOCH: 5, train_loss: 0.01957080273755959
# SEED: 42, FOLD: 2, EPOCH: 5, valid_loss: 0.017206342555582524
# SEED: 42, FOLD: 2, EPOCH: 6, train_loss: 0.019430165977350304
# SEED: 42, FOLD: 2, EPOCH: 6, valid_loss: 0.017208472862839698
# SEED: 42, FOLD: 2, EPOCH: 7, train_loss: 0.019339398715366312
# SEED: 42, FOLD: 2, EPOCH: 7, valid_loss: 0.0170833683013916
# SEED: 42, FOLD: 2, EPOCH: 8, train_loss: 0.019336406737059154
# SEED: 42, FOLD: 2, EPOCH: 8, valid_loss: 0.017178379483520984
# SEED: 42, FOLD: 2, EPOCH: 9, train_loss: 0.019338417000004222
# SEED: 42, FOLD: 2, EPOCH: 9, valid_loss: 0.017134500667452812
# SEED: 42, FOLD: 2, EPOCH: 10, train_loss: 0.019339767696500636
# SEED: 42, FOLD: 2, EPOCH: 10, valid_loss: 0.017210557125508785
# SEED: 42, FOLD: 2, EPOCH: 11, train_loss: 0.01929093002766168
# SEED: 42, FOLD: 2, EPOCH: 11, valid_loss: 0.017086683213710784
# SEED: 42, FOLD: 2, EPOCH: 12, train_loss: 0.019251713503887054
# SEED: 42, FOLD: 2, EPOCH: 12, valid_loss: 0.017132866717875003
# SEED: 42, FOLD: 2, EPOCH: 13, train_loss: 0.01921220451314636
# SEED: 42, FOLD: 2, EPOCH: 13, valid_loss: 0.017064657397568225
# SEED: 42, FOLD: 2, EPOCH: 14, train_loss: 0.019208732358857887
# SEED: 42, FOLD: 2, EPOCH: 14, valid_loss: 0.01703173890709877
# SEED: 42, FOLD: 2, EPOCH: 15, train_loss: 0.019090838375545684
# SEED: 42, FOLD: 2, EPOCH: 15, valid_loss: 0.017002623118460177
# SEED: 42, FOLD: 2, EPOCH: 16, train_loss: 0.01902666846353586
# SEED: 42, FOLD: 2, EPOCH: 16, valid_loss: 0.01690734874457121
# SEED: 42, FOLD: 2, EPOCH: 17, train_loss: 0.018988367220779664
# SEED: 42, FOLD: 2, EPOCH: 17, valid_loss: 0.016916382983326914
# SEED: 42, FOLD: 2, EPOCH: 18, train_loss: 0.018911618904090252
# SEED: 42, FOLD: 2, EPOCH: 18, valid_loss: 0.016735884584486483
# SEED: 42, FOLD: 2, EPOCH: 19, train_loss: 0.018699357925983918
# SEED: 42, FOLD: 2, EPOCH: 19, valid_loss: 0.016599901467561722
# SEED: 42, FOLD: 2, EPOCH: 20, train_loss: 0.018569830044799923
# SEED: 42, FOLD: 2, EPOCH: 20, valid_loss: 0.016541188061237336
# SEED: 42, FOLD: 2, EPOCH: 21, train_loss: 0.01840698245127185
# SEED: 42, FOLD: 2, EPOCH: 21, valid_loss: 0.016467796973884105
# SEED: 42, FOLD: 2, EPOCH: 22, train_loss: 0.018208027703269403
# SEED: 42, FOLD: 2, EPOCH: 22, valid_loss: 0.01631161671131849
# SEED: 42, FOLD: 2, EPOCH: 23, train_loss: 0.017909620451379796
# SEED: 42, FOLD: 2, EPOCH: 23, valid_loss: 0.016173155046999454
# SEED: 42, FOLD: 2, EPOCH: 24, train_loss: 0.017589087388953383
# SEED: 42, FOLD: 2, EPOCH: 24, valid_loss: 0.016126517094671725
# SEED: 42, FOLD: 2, EPOCH: 25, train_loss: 0.017300634777971675
# SEED: 42, FOLD: 2, EPOCH: 25, valid_loss: 0.01608275331556797
# SEED: 42, FOLD: 2, EPOCH: 26, train_loss: 0.01696692729609556
# SEED: 42, FOLD: 2, EPOCH: 26, valid_loss: 0.01597164586186409
# SEED: 42, FOLD: 2, EPOCH: 27, train_loss: 0.01664750803844864
# SEED: 42, FOLD: 2, EPOCH: 27, valid_loss: 0.01595266953110695
# SEED: 42, FOLD: 2, EPOCH: 28, train_loss: 0.016387543571339983
# SEED: 42, FOLD: 2, EPOCH: 28, valid_loss: 0.015944623686373234
# SEED: 42, FOLD: 2, EPOCH: 29, train_loss: 0.01627007825616874
# SEED: 42, FOLD: 2, EPOCH: 29, valid_loss: 0.015930444933474064
# SEED: 42, FOLD: 3, EPOCH: 0, train_loss: 0.5840897899197073
# SEED: 42, FOLD: 3, EPOCH: 0, valid_loss: 0.0664606386423111
# SEED: 42, FOLD: 3, EPOCH: 1, train_loss: 0.02752324594121401
# SEED: 42, FOLD: 3, EPOCH: 1, valid_loss: 0.020062059387564658
# SEED: 42, FOLD: 3, EPOCH: 2, train_loss: 0.02152655222991697
# SEED: 42, FOLD: 3, EPOCH: 2, valid_loss: 0.018602853715419768
# SEED: 42, FOLD: 3, EPOCH: 3, train_loss: 0.02067477114143826
# SEED: 42, FOLD: 3, EPOCH: 3, valid_loss: 0.018039631471037865
# SEED: 42, FOLD: 3, EPOCH: 4, train_loss: 0.019941308579984166
# SEED: 42, FOLD: 3, EPOCH: 4, valid_loss: 0.01745193101465702
# SEED: 42, FOLD: 3, EPOCH: 5, train_loss: 0.01955134217582998
# SEED: 42, FOLD: 3, EPOCH: 5, valid_loss: 0.01766375232487917
# SEED: 42, FOLD: 3, EPOCH: 6, train_loss: 0.019387569582583954
# SEED: 42, FOLD: 3, EPOCH: 6, valid_loss: 0.01728996552526951
# SEED: 42, FOLD: 3, EPOCH: 7, train_loss: 0.019380984650481315
# SEED: 42, FOLD: 3, EPOCH: 7, valid_loss: 0.017098284065723418
# SEED: 42, FOLD: 3, EPOCH: 8, train_loss: 0.019318645883376905
# SEED: 42, FOLD: 3, EPOCH: 8, valid_loss: 0.01720493070781231
# SEED: 42, FOLD: 3, EPOCH: 9, train_loss: 0.019244626126423175
# SEED: 42, FOLD: 3, EPOCH: 9, valid_loss: 0.01723416358232498
# SEED: 42, FOLD: 3, EPOCH: 10, train_loss: 0.019218135219650205
# SEED: 42, FOLD: 3, EPOCH: 10, valid_loss: 0.01727651122957468
# SEED: 42, FOLD: 3, EPOCH: 11, train_loss: 0.019178346230261992
# SEED: 42, FOLD: 3, EPOCH: 11, valid_loss: 0.01717441573739052
# SEED: 42, FOLD: 3, EPOCH: 12, train_loss: 0.01915684912581833
# SEED: 42, FOLD: 3, EPOCH: 12, valid_loss: 0.017275985255837442
# SEED: 42, FOLD: 3, EPOCH: 13, train_loss: 0.019107751066790146
# SEED: 42, FOLD: 3, EPOCH: 13, valid_loss: 0.01708435632288456
# SEED: 42, FOLD: 3, EPOCH: 14, train_loss: 0.019084818863949807
# SEED: 42, FOLD: 3, EPOCH: 14, valid_loss: 0.01708837803453207
# SEED: 42, FOLD: 3, EPOCH: 15, train_loss: 0.019003013186917012
# SEED: 42, FOLD: 3, EPOCH: 15, valid_loss: 0.01695751626044512
# SEED: 42, FOLD: 3, EPOCH: 16, train_loss: 0.018973664500985015
# SEED: 42, FOLD: 3, EPOCH: 16, valid_loss: 0.016880323626101017
# SEED: 42, FOLD: 3, EPOCH: 17, train_loss: 0.018833985628218065
# SEED: 42, FOLD: 3, EPOCH: 17, valid_loss: 0.01690641913563013
# SEED: 42, FOLD: 3, EPOCH: 18, train_loss: 0.018788073547691308
# SEED: 42, FOLD: 3, EPOCH: 18, valid_loss: 0.01683966673910618
# SEED: 42, FOLD: 3, EPOCH: 19, train_loss: 0.018563170575213676
# SEED: 42, FOLD: 3, EPOCH: 19, valid_loss: 0.016741120964288713
# SEED: 42, FOLD: 3, EPOCH: 20, train_loss: 0.018408897586268225
# SEED: 42, FOLD: 3, EPOCH: 20, valid_loss: 0.016819541342556477
# SEED: 42, FOLD: 3, EPOCH: 21, train_loss: 0.01817242958944063
# SEED: 42, FOLD: 3, EPOCH: 21, valid_loss: 0.016560597009956837
# SEED: 42, FOLD: 3, EPOCH: 22, train_loss: 0.01801431901296791
# SEED: 42, FOLD: 3, EPOCH: 22, valid_loss: 0.01643346983939409
# SEED: 42, FOLD: 3, EPOCH: 23, train_loss: 0.01767436340831372
# SEED: 42, FOLD: 3, EPOCH: 23, valid_loss: 0.016329957768321038
# SEED: 42, FOLD: 3, EPOCH: 24, train_loss: 0.01738545814921864
# SEED: 42, FOLD: 3, EPOCH: 24, valid_loss: 0.016313136518001557
# SEED: 42, FOLD: 3, EPOCH: 25, train_loss: 0.017041132931097023
# SEED: 42, FOLD: 3, EPOCH: 25, valid_loss: 0.01620754636824131
# SEED: 42, FOLD: 3, EPOCH: 26, train_loss: 0.016676534721184345
# SEED: 42, FOLD: 3, EPOCH: 26, valid_loss: 0.01616933088749647
# SEED: 42, FOLD: 3, EPOCH: 27, train_loss: 0.016378419435754115
# SEED: 42, FOLD: 3, EPOCH: 27, valid_loss: 0.016148309335112573
# SEED: 42, FOLD: 3, EPOCH: 28, train_loss: 0.016155640892431038
# SEED: 42, FOLD: 3, EPOCH: 28, valid_loss: 0.016130532994866373
# SEED: 42, FOLD: 3, EPOCH: 29, train_loss: 0.016092332688217262
# SEED: 42, FOLD: 3, EPOCH: 29, valid_loss: 0.016124711707234382
# SEED: 42, FOLD: 4, EPOCH: 0, train_loss: 0.582790190214608
# SEED: 42, FOLD: 4, EPOCH: 0, valid_loss: 0.05718128442764282
# SEED: 42, FOLD: 4, EPOCH: 1, train_loss: 0.027147374996522658
# SEED: 42, FOLD: 4, EPOCH: 1, valid_loss: 0.020141699612140657
# SEED: 42, FOLD: 4, EPOCH: 2, train_loss: 0.021629142302538262
# SEED: 42, FOLD: 4, EPOCH: 2, valid_loss: 0.018272583931684495
# SEED: 42, FOLD: 4, EPOCH: 3, train_loss: 0.020666970725671776
# SEED: 42, FOLD: 4, EPOCH: 3, valid_loss: 0.01809338092803955
# SEED: 42, FOLD: 4, EPOCH: 4, train_loss: 0.02004588936411199
# SEED: 42, FOLD: 4, EPOCH: 4, valid_loss: 0.018084559068083764
# SEED: 42, FOLD: 4, EPOCH: 5, train_loss: 0.01956482350724895
# SEED: 42, FOLD: 4, EPOCH: 5, valid_loss: 0.01742368280887604
# SEED: 42, FOLD: 4, EPOCH: 6, train_loss: 0.0194317443917195
# SEED: 42, FOLD: 4, EPOCH: 6, valid_loss: 0.017329447232186795
# SEED: 42, FOLD: 4, EPOCH: 7, train_loss: 0.019417912844999306
# SEED: 42, FOLD: 4, EPOCH: 7, valid_loss: 0.017294898554682733
# SEED: 42, FOLD: 4, EPOCH: 8, train_loss: 0.019321624088246805
# SEED: 42, FOLD: 4, EPOCH: 8, valid_loss: 0.017352042756974696
# SEED: 42, FOLD: 4, EPOCH: 9, train_loss: 0.019283441598622168
# SEED: 42, FOLD: 4, EPOCH: 9, valid_loss: 0.017161926180124285
# SEED: 42, FOLD: 4, EPOCH: 10, train_loss: 0.01932155973195624
# SEED: 42, FOLD: 4, EPOCH: 10, valid_loss: 0.017198957093060015
# SEED: 42, FOLD: 4, EPOCH: 11, train_loss: 0.01929805922594403
# SEED: 42, FOLD: 4, EPOCH: 11, valid_loss: 0.017279861196875572
# SEED: 42, FOLD: 4, EPOCH: 12, train_loss: 0.019220915597667095
# SEED: 42, FOLD: 4, EPOCH: 12, valid_loss: 0.0172091843187809
# SEED: 42, FOLD: 4, EPOCH: 13, train_loss: 0.019249896056392567
# SEED: 42, FOLD: 4, EPOCH: 13, valid_loss: 0.01728062503039837
# SEED: 42, FOLD: 4, EPOCH: 14, train_loss: 0.019184063283764586
# SEED: 42, FOLD: 4, EPOCH: 14, valid_loss: 0.017146129421889783
# SEED: 42, FOLD: 4, EPOCH: 15, train_loss: 0.019123918560593308
# SEED: 42, FOLD: 4, EPOCH: 15, valid_loss: 0.017203430868685244
# SEED: 42, FOLD: 4, EPOCH: 16, train_loss: 0.019035639526436523
# SEED: 42, FOLD: 4, EPOCH: 16, valid_loss: 0.01702443737536669
# SEED: 42, FOLD: 4, EPOCH: 17, train_loss: 0.018996798750139824
# SEED: 42, FOLD: 4, EPOCH: 17, valid_loss: 0.017039022296667098
# SEED: 42, FOLD: 4, EPOCH: 18, train_loss: 0.018815472392606086
# SEED: 42, FOLD: 4, EPOCH: 18, valid_loss: 0.0168209969624877
# SEED: 42, FOLD: 4, EPOCH: 19, train_loss: 0.018718926438770326
# SEED: 42, FOLD: 4, EPOCH: 19, valid_loss: 0.016725068241357804
# SEED: 42, FOLD: 4, EPOCH: 20, train_loss: 0.01854441298463312
# SEED: 42, FOLD: 4, EPOCH: 20, valid_loss: 0.01662263263016939
# SEED: 42, FOLD: 4, EPOCH: 21, train_loss: 0.018307937980711866
# SEED: 42, FOLD: 4, EPOCH: 21, valid_loss: 0.01657764732837677
# SEED: 42, FOLD: 4, EPOCH: 22, train_loss: 0.01816157689381416
# SEED: 42, FOLD: 4, EPOCH: 22, valid_loss: 0.016461884789168834
# SEED: 42, FOLD: 4, EPOCH: 23, train_loss: 0.01790081631062793
# SEED: 42, FOLD: 4, EPOCH: 23, valid_loss: 0.01638496309518814
# SEED: 42, FOLD: 4, EPOCH: 24, train_loss: 0.017593106983520953
# SEED: 42, FOLD: 4, EPOCH: 24, valid_loss: 0.016231426522135734
# SEED: 42, FOLD: 4, EPOCH: 25, train_loss: 0.01725254809091083
# SEED: 42, FOLD: 4, EPOCH: 25, valid_loss: 0.016190623342990876
# SEED: 42, FOLD: 4, EPOCH: 26, train_loss: 0.016834558418565463
# SEED: 42, FOLD: 4, EPOCH: 26, valid_loss: 0.016063078194856643
# SEED: 42, FOLD: 4, EPOCH: 27, train_loss: 0.016513873290802752
# SEED: 42, FOLD: 4, EPOCH: 27, valid_loss: 0.016058563478291033
# SEED: 42, FOLD: 4, EPOCH: 28, train_loss: 0.016281178734284276
# SEED: 42, FOLD: 4, EPOCH: 28, valid_loss: 0.01602333303540945
# SEED: 42, FOLD: 4, EPOCH: 29, train_loss: 0.016144665534652415
# SEED: 42, FOLD: 4, EPOCH: 29, valid_loss: 0.016034081988036634
# SEED: 42, FOLD: 5, EPOCH: 0, train_loss: 0.5840167128512649
# SEED: 42, FOLD: 5, EPOCH: 0, valid_loss: 0.05443091556429863
# SEED: 42, FOLD: 5, EPOCH: 1, train_loss: 0.02734425908499429
# SEED: 42, FOLD: 5, EPOCH: 1, valid_loss: 0.02006906919181347
# SEED: 42, FOLD: 5, EPOCH: 2, train_loss: 0.021623303784298248
# SEED: 42, FOLD: 5, EPOCH: 2, valid_loss: 0.01964550793170929
# SEED: 42, FOLD: 5, EPOCH: 3, train_loss: 0.02043298554613071
# SEED: 42, FOLD: 5, EPOCH: 3, valid_loss: 0.01786345601081848
# SEED: 42, FOLD: 5, EPOCH: 4, train_loss: 0.02012738771736622
# SEED: 42, FOLD: 5, EPOCH: 4, valid_loss: 0.017539717704057694
# SEED: 42, FOLD: 5, EPOCH: 5, train_loss: 0.01963364747257865
# SEED: 42, FOLD: 5, EPOCH: 5, valid_loss: 0.017590041309595107
# SEED: 42, FOLD: 5, EPOCH: 6, train_loss: 0.019401465029436713
# SEED: 42, FOLD: 5, EPOCH: 6, valid_loss: 0.017392046451568603
# SEED: 42, FOLD: 5, EPOCH: 7, train_loss: 0.01933150230368384
# SEED: 42, FOLD: 5, EPOCH: 7, valid_loss: 0.01741518560796976
# SEED: 42, FOLD: 5, EPOCH: 8, train_loss: 0.019252359132174733
# SEED: 42, FOLD: 5, EPOCH: 8, valid_loss: 0.017367259562015534
# SEED: 42, FOLD: 5, EPOCH: 9, train_loss: 0.01926016641565326
# SEED: 42, FOLD: 5, EPOCH: 9, valid_loss: 0.017319884970784186
# SEED: 42, FOLD: 5, EPOCH: 10, train_loss: 0.019252638566960283
# SEED: 42, FOLD: 5, EPOCH: 10, valid_loss: 0.017436993308365345
# SEED: 42, FOLD: 5, EPOCH: 11, train_loss: 0.019328687973573906
# SEED: 42, FOLD: 5, EPOCH: 11, valid_loss: 0.017270298823714256
# SEED: 42, FOLD: 5, EPOCH: 12, train_loss: 0.019234850647903624
# SEED: 42, FOLD: 5, EPOCH: 12, valid_loss: 0.017486401945352555
# SEED: 42, FOLD: 5, EPOCH: 13, train_loss: 0.019208892812432887
# SEED: 42, FOLD: 5, EPOCH: 13, valid_loss: 0.017210451364517213
# SEED: 42, FOLD: 5, EPOCH: 14, train_loss: 0.01918124335304815
# SEED: 42, FOLD: 5, EPOCH: 14, valid_loss: 0.017204851992428303
# SEED: 42, FOLD: 5, EPOCH: 15, train_loss: 0.01914342568845165
# SEED: 42, FOLD: 5, EPOCH: 15, valid_loss: 0.01723709873855114
# SEED: 42, FOLD: 5, EPOCH: 16, train_loss: 0.01907457975151182
# SEED: 42, FOLD: 5, EPOCH: 16, valid_loss: 0.017159418873488902
# SEED: 42, FOLD: 5, EPOCH: 17, train_loss: 0.019008283180241684
# SEED: 42, FOLD: 5, EPOCH: 17, valid_loss: 0.016986167952418328
# SEED: 42, FOLD: 5, EPOCH: 18, train_loss: 0.018922266835460857
# SEED: 42, FOLD: 5, EPOCH: 18, valid_loss: 0.016956100016832353
# SEED: 42, FOLD: 5, EPOCH: 19, train_loss: 0.01872427566420464
# SEED: 42, FOLD: 5, EPOCH: 19, valid_loss: 0.01708950076252222
# SEED: 42, FOLD: 5, EPOCH: 20, train_loss: 0.018624945942844664
# SEED: 42, FOLD: 5, EPOCH: 20, valid_loss: 0.01675440985709429
# SEED: 42, FOLD: 5, EPOCH: 21, train_loss: 0.018433147509183203
# SEED: 42, FOLD: 5, EPOCH: 21, valid_loss: 0.016687727607786654
# SEED: 42, FOLD: 5, EPOCH: 22, train_loss: 0.018245390876113963
# SEED: 42, FOLD: 5, EPOCH: 22, valid_loss: 0.016571983061730862
# SEED: 42, FOLD: 5, EPOCH: 23, train_loss: 0.017989787621562985
# SEED: 42, FOLD: 5, EPOCH: 23, valid_loss: 0.016422862596809865
# SEED: 42, FOLD: 5, EPOCH: 24, train_loss: 0.017671381079015277
# SEED: 42, FOLD: 5, EPOCH: 24, valid_loss: 0.01630239050835371
# SEED: 42, FOLD: 5, EPOCH: 25, train_loss: 0.017386471637252238
# SEED: 42, FOLD: 5, EPOCH: 25, valid_loss: 0.016232286728918553
# SEED: 42, FOLD: 5, EPOCH: 26, train_loss: 0.017035385973903597
# SEED: 42, FOLD: 5, EPOCH: 26, valid_loss: 0.016147671714425087
# SEED: 42, FOLD: 5, EPOCH: 27, train_loss: 0.016753703083361493
# SEED: 42, FOLD: 5, EPOCH: 27, valid_loss: 0.01607466649264097
# SEED: 42, FOLD: 5, EPOCH: 28, train_loss: 0.0165174397240792
# SEED: 42, FOLD: 5, EPOCH: 28, valid_loss: 0.016048819981515406
# SEED: 42, FOLD: 5, EPOCH: 29, train_loss: 0.01645977422595024
# SEED: 42, FOLD: 5, EPOCH: 29, valid_loss: 0.016040663160383703
# SEED: 42, FOLD: 6, EPOCH: 0, train_loss: 0.5851991203974705
# SEED: 42, FOLD: 6, EPOCH: 0, valid_loss: 0.05835823386907577
# SEED: 42, FOLD: 6, EPOCH: 1, train_loss: 0.027416478424352044
# SEED: 42, FOLD: 6, EPOCH: 1, valid_loss: 0.019984027743339537
# SEED: 42, FOLD: 6, EPOCH: 2, train_loss: 0.021929733619904843
# SEED: 42, FOLD: 6, EPOCH: 2, valid_loss: 0.018438504040241242
# SEED: 42, FOLD: 6, EPOCH: 3, train_loss: 0.02082851173064741
# SEED: 42, FOLD: 6, EPOCH: 3, valid_loss: 0.01764578890055418
# SEED: 42, FOLD: 6, EPOCH: 4, train_loss: 0.020069963038981366
# SEED: 42, FOLD: 6, EPOCH: 4, valid_loss: 0.017514151409268378
# SEED: 42, FOLD: 6, EPOCH: 5, train_loss: 0.019701842535413853
# SEED: 42, FOLD: 6, EPOCH: 5, valid_loss: 0.01731319472193718
# SEED: 42, FOLD: 6, EPOCH: 6, train_loss: 0.019534194708934853
# SEED: 42, FOLD: 6, EPOCH: 6, valid_loss: 0.017303678616881372
# SEED: 42, FOLD: 6, EPOCH: 7, train_loss: 0.019367398263341714
# SEED: 42, FOLD: 6, EPOCH: 7, valid_loss: 0.01717901010066271
# SEED: 42, FOLD: 6, EPOCH: 8, train_loss: 0.019396022101547443
# SEED: 42, FOLD: 6, EPOCH: 8, valid_loss: 0.017100040428340436
# SEED: 42, FOLD: 6, EPOCH: 9, train_loss: 0.019382368557814028
# SEED: 42, FOLD: 6, EPOCH: 9, valid_loss: 0.017208412140607834
# SEED: 42, FOLD: 6, EPOCH: 10, train_loss: 0.01933874249407629
# SEED: 42, FOLD: 6, EPOCH: 10, valid_loss: 0.016984263993799688
# SEED: 42, FOLD: 6, EPOCH: 11, train_loss: 0.019310023065428346
# SEED: 42, FOLD: 6, EPOCH: 11, valid_loss: 0.017203538566827773
# SEED: 42, FOLD: 6, EPOCH: 12, train_loss: 0.019262388373921517
# SEED: 42, FOLD: 6, EPOCH: 12, valid_loss: 0.017226426750421523
# SEED: 42, FOLD: 6, EPOCH: 13, train_loss: 0.01926755061259075
# SEED: 42, FOLD: 6, EPOCH: 13, valid_loss: 0.017120327055454253
# SEED: 42, FOLD: 6, EPOCH: 14, train_loss: 0.01922257854064711
# SEED: 42, FOLD: 6, EPOCH: 14, valid_loss: 0.017022151164710522
# SEED: 42, FOLD: 6, EPOCH: 15, train_loss: 0.019195972580690772
# SEED: 42, FOLD: 6, EPOCH: 15, valid_loss: 0.016900985725224017
# SEED: 42, FOLD: 6, EPOCH: 16, train_loss: 0.01906650783304049
# SEED: 42, FOLD: 6, EPOCH: 16, valid_loss: 0.016920248121023176
# SEED: 42, FOLD: 6, EPOCH: 17, train_loss: 0.01903475043015415
# SEED: 42, FOLD: 6, EPOCH: 17, valid_loss: 0.016884034574031828
# SEED: 42, FOLD: 6, EPOCH: 18, train_loss: 0.018930514843589593
# SEED: 42, FOLD: 6, EPOCH: 18, valid_loss: 0.016640299819409846
# SEED: 42, FOLD: 6, EPOCH: 19, train_loss: 0.018789297387916213
# SEED: 42, FOLD: 6, EPOCH: 19, valid_loss: 0.016619872599840164
# SEED: 42, FOLD: 6, EPOCH: 20, train_loss: 0.01860246788330224
# SEED: 42, FOLD: 6, EPOCH: 20, valid_loss: 0.01662330262362957
# SEED: 42, FOLD: 6, EPOCH: 21, train_loss: 0.018484100490352328
# SEED: 42, FOLD: 6, EPOCH: 21, valid_loss: 0.01645085521042347
# SEED: 42, FOLD: 6, EPOCH: 22, train_loss: 0.018233628721819037
# SEED: 42, FOLD: 6, EPOCH: 22, valid_loss: 0.01633172173053026
# SEED: 42, FOLD: 6, EPOCH: 23, train_loss: 0.017985066506682204
# SEED: 42, FOLD: 6, EPOCH: 23, valid_loss: 0.01626384638249874
# SEED: 42, FOLD: 6, EPOCH: 24, train_loss: 0.017660053054086206
# SEED: 42, FOLD: 6, EPOCH: 24, valid_loss: 0.016149471513926983
# SEED: 42, FOLD: 6, EPOCH: 25, train_loss: 0.017356543199849778
# SEED: 42, FOLD: 6, EPOCH: 25, valid_loss: 0.01605172999203205
# SEED: 42, FOLD: 6, EPOCH: 26, train_loss: 0.01705170088276571
# SEED: 42, FOLD: 6, EPOCH: 26, valid_loss: 0.016016016229987145
# SEED: 42, FOLD: 6, EPOCH: 27, train_loss: 0.01671901682936618
# SEED: 42, FOLD: 6, EPOCH: 27, valid_loss: 0.01600761905312538
# SEED: 42, FOLD: 6, EPOCH: 28, train_loss: 0.016506978012874825
# SEED: 42, FOLD: 6, EPOCH: 28, valid_loss: 0.015998162627220154
# SEED: 42, FOLD: 6, EPOCH: 29, train_loss: 0.016362088776770093
# SEED: 42, FOLD: 6, EPOCH: 29, valid_loss: 0.016006554774940014

# %% [markdown]
# #### Save OOF Predictions to CSV

# %%
# Saving OOF predictions on non-control set for analysis
validation_predictions.to_csv('unprocessed_validation_predictions.csv', index=False)

# %% [markdown]
# <a id='Results'></a>
# # Results

# %% [markdown]
# ## Results - Raw

# %% [markdown]
# ### Plot Validation Loss by Fold

# %%
# Plot the validation loss for each fold over the epochs
# valid_loss_array is an array of the validaiton loss for each fold for each epoch
fold_names = [f"Fold_{fold}" for fold in range(NFOLDS)]
val_loss_df = pd.DataFrame(data=valid_loss_array, columns=fold_names)
p = sns.lineplot(data=val_loss_df, dashes=False)
p.set(ylim=(0.014, 0.020))
# Out:
# [(0.014, 0.02)]

# %% [markdown]
# ### CV log_loss

# %%
raw_y_true = target[target_cols].values
raw_y_pred = validation_predictions[target_cols].values

raw_scores = []
for i in range(len(target_cols)):
    raw_scores.append(log_loss(raw_y_true[:, i], raw_y_pred[:, i]))
    
raw_scores_arr = np.asarray(raw_scores)
print("Raw CV log_loss: ", raw_scores_arr.mean())
# Out:
# Raw CV log_loss:  0.01600459431257697

# %%
raw_scores_df = pd.DataFrame(raw_scores_arr, index=target_cols)
raw_scores_df = raw_scores_df.sort_values(by=raw_scores_df.columns[0], ascending=True)
raw_scores_df.columns = ["Raw_Log_Loss"]
# raw_scores_df.tail(20).plot.barh()

# %% [markdown]
# ### ROC AUC

# %%
roc_auc = roc_auc_score(raw_y_true, raw_y_pred)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(raw_y_true.shape[1]):
    roc_auc[i] = roc_auc_score(raw_y_true[:, i], raw_y_pred[:, i])
    fpr[i], tpr[i], _ = roc_curve(raw_y_true[:, i], raw_y_pred[:, i])
roc_arr_raw = np.asarray(list(roc_auc.values()))

# %%
plt.hist(roc_arr_raw, bins = 30)
plt.title(f'ROC Scores by Label: {np.round(roc_arr_raw.mean(), 4)} Average')

raw_roc_mean = roc_arr_raw.mean()
print(f"Raw roc_score: {np.round(raw_roc_mean, 4)}")
# Out:
# Raw roc_score: 0.7804

# %%
bad_cols = np.argwhere(roc_arr_raw < 0.5)
for col in bad_cols:
    print(target_cols[col[0]])
    plt.figure()
    lw = 2
    plt.plot(fpr[col[0]], tpr[col[0]], color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[col[0]])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()
# Out:
# atp-sensitive_potassium_channel_antagonist
# erbb2_inhibitor

# %% [markdown]
# ## Results - Adjusted
# CV Loss reported above and in the plots above are only for non-control cases.
# Below is the adjusted CV_loss for when control cases are hard-coded to 0 and included in loss statistics.

# %%
# train_targets_scored is the original unaltered df.
train_temp = pd.read_csv('../input/lish-moa/train_features.csv')
valid_results = train_targets_scored.drop(columns=target_cols).merge(validation_predictions, on='sig_id', how='left').fillna(0)

if FORCE_BAD_COLS:
    for col in bad_cols:
        valid_results.iloc[:, col[0]+1] = 1.75/3624
        
valid_results.loc[train_temp['cp_type'] == 'ctl_vehicle', 1:] = 0

adj_y_true = train_targets_scored[target_cols].values
adj_y_pred = valid_results[target_cols].values

# %% [markdown]
# ### CV LogLoss

# %%
adj_scores = []
for i in range(len(target_cols)):
    adj_scores.append(log_loss(adj_y_true[:, i], adj_y_pred[:, i]))
    
adj_scores_arr = np.asarray(adj_scores)
print("Adj CV log_loss: ", adj_scores_arr.mean())
# Out:
# Adj CV log_loss:  0.014749886220585652

# %%
adj_scores_df = pd.DataFrame(adj_scores_arr, index=target_cols)
adj_scores_df = adj_scores_df.sort_values(by=adj_scores_df.columns[0], ascending=True)
adj_scores_df.columns = ["Adj_Log_Loss"]

log_loss_df = raw_scores_df.merge(adj_scores_df, left_index=True, right_index=True)

fig, ax = plt.subplots(figsize=(20, 10))
log_loss_df.tail(20).plot.barh(ax=ax)
plt.show()

# %% [markdown]
# ### ROC AUC

# %%
roc_auc = roc_auc_score(adj_y_true, adj_y_pred)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(adj_y_true.shape[1]):
    roc_auc[i] = roc_auc_score(adj_y_true[:, i], adj_y_pred[:, i])
    fpr[i], tpr[i], _ = roc_curve(adj_y_true[:, i], adj_y_pred[:, i])
roc_arr_adj = np.asarray(list(roc_auc.values()))

# %%
plt.hist(roc_arr_adj, bins = 30)
plt.title(f'ROC Scores by Label: {np.round(roc_arr_adj.mean(), 4)} Average')

adj_roc_mean = roc_arr_adj.mean()
print(f"Adj roc_score: {np.round(adj_roc_mean, 4)}")
# Out:
# Adj roc_score: 0.801

# %%
# Using roc_arr_raw to show the improvement on earlier problem examples
bad_cols = np.argwhere(roc_arr_raw < 0.5)
for col in bad_cols:
    print(target_cols[col[0]])
    plt.figure()
    lw = 2
    plt.plot(fpr[col[0]], tpr[col[0]], color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[col[0]])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()
# Out:
# atp-sensitive_potassium_channel_antagonist
# erbb2_inhibitor

# %% [markdown]
# ### Collective Stats

# %%
print(f"Raw CV log_loss: {raw_scores_arr.mean()}  ")
print(f"Adj CV log_loss: {adj_scores_arr.mean()}  ")
print(f"Raw roc_score: {np.round(raw_roc_mean, 4)}  ")
print(f"Adj roc_score: {np.round(adj_roc_mean, 4)}  ")
# Out:
# Raw CV log_loss: 0.01600459431257697
# Adj CV log_loss: 0.014749886220585652
# Raw roc_score: 0.7804
# Adj roc_score: 0.801

# %% [markdown]
# <a id='Prepare_Submission_File'></a>
# # Prepare Submission File

# %%
# Here is the part where cp_type == ctl_vehicle is handled. 
# We merge on sig_id, so the sig_id's missing from our test predictions(only the ctl-vehicle set) remain 0.
test_temp = pd.read_csv('../input/lish-moa/test_features.csv')

sub = sample_submission.drop(columns=target_cols).merge(test_predictions, on='sig_id', how='left').fillna(0)

if FORCE_BAD_COLS:
    for col in bad_cols:
        sub.iloc[:, col[0]] = 1.75/3624

sub.loc[test_temp['cp_type'] == 'ctl_vehicle', 1:] = 0
        
sub.to_csv('submission.csv', index=False)
